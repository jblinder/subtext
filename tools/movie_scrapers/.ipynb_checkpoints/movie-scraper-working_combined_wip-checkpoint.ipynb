# %%
import requests
import string
import time
from bs4 import BeautifulSoup
import re
import pprint 
pp = pprint.PrettyPrinter(indent=4)



def get_page(url):
    response = requests.get(url)
    page = response.text
    return page

'''
Parse film list
'''

def get_film_list(url):
    page = get_page(url)
    films_list = {}
    
    list_soup=BeautifulSoup(page,"html5lib")
    tables=list_soup.find_all("table")
    
    tables=list_soup.find_all("table")
    rows=[row for row in tables[2].find_all('tr')]
    rows.pop(0) #remove header
    for i,r in enumerate(rows):
        items = r.find_all('td')
        link=items[-1].find('a')['href']
        title= items[-1].find('a').text
        films_list[title] = "%s%s"%(base_url,link)
    return films_list

'''
Parse film details
'''
def get_film_details(url,title):
    page = get_page(url)
    film = {}
    film['title'] = title

    page_soup = BeautifulSoup(page,"html5lib")
    cast_table = get_table_values(page_soup,'The Players')
    sub_genre_table = get_table_values(page_soup,'Genres')
    
    tables = page_soup.find_all("table")
    parse_image(film,page_soup)
    parse_details(film,tables[5])
    parse_finances2(film,page_soup)
    if cast_table is not None:
        parse_cast(film,cast_table,page_soup)
    if sub_genre_table is not None:
        parse_sub_genre(film,sub_genre_table)
    return film
    
def clean_string(raw_string):
    printable = set(string.printable)
    clean=[s for s in raw_string if s in printable]
    return ''.join(clean)

'''Parse poster image'''
def parse_image(film,page_soup):
    poster_img = page_soup.find_all("img")[6]['src']
    film['image'] = poster_img
    
'''Parse details table'''
def parse_details(film,table):
    rows=[row for row in table.find_all('tr')]
    rows.pop(0) # remove header
    prop_map = {"Distributor":"distributor", "Release Date": "release_date","Genre":"genre","Runtime":"duration","MPAA Rating":"rating","Production Budget":"budget"}
    for row in rows:
        # each row will have a few cells: (td~ cell tag)
        items=row.find_all('td')
        [parse_details_row(item,film,prop_map) for item in items]

'''Parse dtails table rows'''
def parse_details_row(row,film,prop_map):
    data = row.text.split(':')
    text = data[1]
    prop = prop_map[data[0]]
    film[prop] = text
    
'''Parse finance table'''
def parse_finances(film,table):
    rows=[row for row in table.find_all('tr')]
    prop_map = {0:"gross_domestic",1:"gross_foreign"}
    for i,row in enumerate(rows):
    # prevent out of index error on irregular cell
        if i < len(rows)-2:
            items=row.find_all('td')
            film[prop_map[i]] = clean_string(items[1].text)
            
def parse_finances2(film,page_soup):
    film['gross_domestic'] = get_movie_value(page_soup,'Domestic')
    film['gross_foreign'] = get_movie_value(page_soup,'Foreign')
    film['gross_worldwide'] = get_movie_value(page_soup,'Worldwide')
    
    


'''Parse cast table'''
def parse_cast(film,table,page_soup):
    rows=[row for row in table.find_all('tr')]
    #print(rows)

    film['director'] = rows[0].text.split(':')[1]
    cast = [row.text for row in rows[1].find_all('a')]
    cast.pop(0)
    film['cast'] = ", ".join(cast) # comma seperated list

'''Parse genre table'''
def parse_sub_genre(film,table):
    rows=[row for row in table.find_all('tr')]
    rows.pop(0) # remove header
    sub_genres = []
    for row in rows:
        g = row.find('a').text
        sub_genres.append(g)
    sg = clean_string(', '.join(sub_genres)) # comma seperated list
    film['sub_genres'] = sg

    
base_url = 'http://www.boxofficemojo.com/'
url = 'http://www.boxofficemojo.com/yearly/'

def get_movie_value(soup, field_name):
    '''Grab a value from boxofficemojo HTML
    
    Takes a string attribute of a movie on the page and
    returns the string in the next sibling object
    (the value for that attribute)
    or None if nothing is found.
    '''
    obj = soup.find(text=re.compile(field_name))
    if not obj: 
        return None
    # this works for most of the values
    next_sibling = obj.findNextSibling()
    if next_sibling:
        return next_sibling.text 
    else:
        return None

def get_table_values(soup, field_name):
    '''Grab a value from boxofficemojo HTML
    
    Takes a string attribute of a movie on the page and
    returns the string in the next sibling object
    (the value for that attribute)
    or None if nothing is found.
    '''
    obj = soup.find('div',text=re.compile(field_name))
    if obj == None:
        return None
    table = obj.findNext('table')
    return table


'''Get film list by metric'''
film_list = get_film_list(url)

url = 'http://www.boxofficemojo.com//movies/?id=marvel2017b.htm'
films = []

for film,url in film_list.items():
    print(film)
    title = film
    film = get_film_details(url,title)
    films.append(film)
    #time.sleep(1)

pp.pprint(films)
# Out:
# Black Panther
# Star Wars: The Last Jedi
# Rogue One
# Star Wars: The Force Awakens
# American Sniper
# Catching Fire
# The Avengers
# Harry Potter / Deathly Hallows (P2)
# Toy Story 3
# Avatar
# The Dark Knight
# Spider-Man 3
# Dead Man's Chest
# Revenge of the Sith
# Shrek 2
# Return of the King
# Spider-Man
# Harry Potter / Sorcerer's Stone
# The Grinch
# The Phantom Menace
# Saving Private Ryan
# Titanic
# Independence Day
# Toy Story
# Forrest Gump
# Jurassic Park
# Aladdin
# Terminator 2
# Home Alone
# Batman
# Rain Man
# Three Men and a Baby
# Top Gun
# Back to the Future
# Beverly Hills Cop
# Return of the Jedi
# E.T.
# Raiders / Lost Ark
# The Empire Strikes Back
# [   {   'budget': ' N/A',
#         'cast': "Chadwick Boseman, Lupita Nyong'o, Michael B. Jordan, Angela "
#                 'Bassett, Martin Freeman, Forest Whitaker, Andy Serkis',
#         'director': 'Ryan Coogler',
#         'distributor': ' Buena Vista',
#         'duration': ' 2 hrs. 20 min.',
#         'genre': ' Action / Adventure',
#         'gross_domestic': None,
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMTg1MTY2MjYzNV5BMl5BanBnXkFtZTgwMTc4NTMwNDI@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' February 16, 2018',
#         'sub_genres': '3D, Comic Book Adaptation, IMAX (Feature-length), '
#                       'Superhero, Superhero - Origin',
#         'title': 'Black Panther'},
#     {   'budget': ' N/A',
#         'cast': 'Rian Johnson',
#         'director': 'Rian Johnson',
#         'distributor': ' Buena Vista',
#         'duration': ' 2 hrs. 31 min.',
#         'genre': ' Sci-Fi Fantasy',
#         'gross_domestic': None,
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMjQ1MzcxNjg4N15BMl5BanBnXkFtZTgwNzgwMjY4MzI@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' December 15, 2017',
#         'sub_genres': '3D, Action Heroine, IMAX (Feature-length), Sci-Fi - '
#                       'Adventure',
#         'title': 'Star Wars: The Last Jedi'},
#     {   'budget': ' $200 million',
#         'cast': 'Chris Weitz, Tony Gilroy',
#         'director': 'Gareth Edwards',
#         'distributor': ' Buena Vista',
#         'duration': ' 2 hrs. 13 min.',
#         'genre': ' Sci-Fi Adventure',
#         'gross_domestic': '$532,177,324',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMjEwMzMxODIzOV5BMl5BanBnXkFtZTgwNzg3OTAzMDI@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' December 16, 2016',
#         'sub_genres': '3D, Action Heroine, IMAX (Feature-length), Prequel, '
#                       'Sci-Fi - Adventure',
#         'title': 'Rogue One'},
#     {   'budget': ' $245 million',
#         'cast': 'J.J. Abrams, Michael Arndt, Lawrence Kasdan',
#         'director': 'J.J. Abrams',
#         'distributor': ' Buena Vista',
#         'duration': ' 2 hrs. 16 min.',
#         'genre': ' Sci-Fi Fantasy',
#         'gross_domestic': '$936,662,225',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BOTAzODEzNDAzMl5BMl5BanBnXkFtZTgwMDU1MTgzNzE@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' December 18, 2015',
#         'sub_genres': '3D, Action Heroine, IMAX (Feature-length), Sci-Fi - '
#                       'Adventure',
#         'title': 'Star Wars: The Force Awakens'},
#     {   'budget': ' $58.8 million',
#         'cast': 'Jason Dean Hall',
#         'director': 'Clint Eastwood',
#         'distributor': ' Warner Bros.',
#         'duration': ' 2 hrs. 12 min.',
#         'genre': ' Drama',
#         'gross_domestic': '$350,126,372',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMTkxNzI3ODI4Nl5BMl5BanBnXkFtZTgwMjkwMjY4MjE@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' R',
#         'release_date': ' December 25, 2014',
#         'sub_genres': 'IMAX (Feature-length), Travelogue - Middle East',
#         'title': 'American Sniper'},
#     {   'budget': ' $130 million',
#         'cast': 'Michael Arndt, Simon Beaufoy',
#         'director': 'Francis Lawrence',
#         'distributor': ' Lionsgate',
#         'duration': ' 2 hrs. 26 min.',
#         'genre': ' Action / Adventure',
#         'gross_domestic': '$424,668,047',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMTAyMjQ3OTAxMzNeQTJeQWpwZ15BbWU4MDU0NzA1MzAx._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' November 22, 2013',
#         'sub_genres': 'Action Heroine, IMAX (Feature-length), Post-Apocalypse, '
#                       'Sci-Fi - Based on Book, Young-Adult Book Adaptations',
#         'title': 'Catching Fire'},
#     {   'budget': ' $220 million',
#         'cast': 'Zak Penn, Joss Whedon',
#         'director': 'Joss Whedon',
#         'distributor': ' Buena Vista',
#         'duration': ' 2 hrs. 22 min.',
#         'genre': ' Action / Adventure',
#         'gross_domestic': '$623,357,910',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMTk2NTI1MTU4N15BMl5BanBnXkFtZTcwODg0OTY0Nw@@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' May 4, 2012',
#         'sub_genres': '3D, Comic Book Adaptation, IMAX (Feature-length), '
#                       'Sci-Fi - Alien Invasion, Superhero',
#         'title': 'The Avengers'},
#     {   'budget': ' N/A',
#         'cast': 'Steve Kloves',
#         'director': 'David Yates',
#         'distributor': ' Warner Bros.',
#         'duration': ' 2 hrs. 10 min.',
#         'genre': ' Fantasy',
#         'gross_domestic': '$381,011,219',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMjIyZGU4YzUtNDkzYi00ZDRhLTljYzctYTMxMDQ4M2E0Y2YxXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' July 15, 2011',
#         'sub_genres': "3D, Dragon - Supporting Role, Family - Children's Book "
#                       'Adaptation, Fantasy - Live Action, IMAX '
#                       '(Feature-length), Young-Adult Book Adaptations',
#         'title': 'Harry Potter / Deathly Hallows (P2)'},
#     {   'budget': ' $200 million',
#         'cast': 'Michael Arndt, John Lasseter, Andrew Stanton, Lee Unkrich',
#         'director': 'Lee Unkrich',
#         'distributor': ' Buena Vista',
#         'duration': ' 1 hrs. 43 min.',
#         'genre': ' Animation',
#         'gross_domestic': '$415,004,880',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMTgxOTY4Mjc0MF5BMl5BanBnXkFtZTcwNTA4MDQyMw@@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' G',
#         'release_date': ' June 18, 2010',
#         'sub_genres': '3D, Animation, Animation - Computer, IMAX '
#                       '(Feature-length), Toys Come to Life',
#         'title': 'Toy Story 3'},
#     {   'budget': ' $237 million',
#         'cast': 'James Cameron',
#         'director': 'James Cameron',
#         'distributor': ' Fox',
#         'duration': ' 2 hrs. 40 min.',
#         'genre': ' Sci-Fi Adventure',
#         'gross_domestic': '$749,766,139',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMTYwOTEwNjAzMl5BMl5BanBnXkFtZTcwODc5MTUwMw@@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' December 18, 2009',
#         'sub_genres': '3D, CGI Star, Disability - Paraplegic / Quadriplegic, '
#                       'Environmentalist, IMAX (Feature-length), Sci-Fi - '
#                       'Adventure',
#         'title': 'Avatar'},
#     {   'budget': ' $185 million',
#         'cast': 'David S. Goyer, Christopher Nolan',
#         'director': 'Christopher Nolan',
#         'distributor': ' Warner Bros.',
#         'duration': ' 2 hrs. 30 min.',
#         'genre': ' Action / Adventure',
#         'gross_domestic': '$533,345,358',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' July 18, 2008',
#         'sub_genres': 'Comic Book Adaptation, IMAX (Feature-length), Superhero',
#         'title': 'The Dark Knight'},
#     {   'budget': ' $258 million',
#         'cast': 'Alvin Sargent',
#         'director': 'Sam Raimi',
#         'distributor': ' Sony / Columbia',
#         'duration': ' 2 hrs. 20 min.',
#         'genre': ' Action / Adventure',
#         'gross_domestic': '$336,530,303',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BYTk3MDljOWQtNGI2My00OTEzLTlhYjQtOTQ4ODM2MzUwY2IwXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' May 4, 2007',
#         'sub_genres': 'Comic Book Adaptation, IMAX (Feature-length), Superhero',
#         'title': 'Spider-Man 3'},
#     {   'budget': ' $225 million',
#         'cast': 'Stuart Beattie, Ted Elliott, Terry Rossio',
#         'director': 'Gore Verbinski',
#         'distributor': ' Buena Vista',
#         'duration': ' 2 hrs. 31 min.',
#         'genre': ' Period Adventure',
#         'gross_domestic': '$423,315,812',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMTcwODc1MTMxM15BMl5BanBnXkFtZTYwMDg1NzY3._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' July 7, 2006',
#         'sub_genres': 'Adventure - Period, Pirate, Swashbuckler, Treasure Hunt',
#         'title': "Dead Man's Chest"},
#     {   'budget': ' $113 million',
#         'cast': 'George Lucas',
#         'director': 'George Lucas',
#         'distributor': ' Fox',
#         'duration': ' 2 hrs. 26 min.',
#         'genre': ' Sci-Fi Fantasy',
#         'gross_domestic': '$380,270,577',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BNTc4MTc3NTQ5OF5BMl5BanBnXkFtZTcwOTg0NjI4NA@@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' May 19, 2005',
#         'sub_genres': 'Prequel, Sci-Fi - Adventure',
#         'title': 'Revenge of the Sith'},
#     {   'budget': ' $150 million',
#         'cast': 'J. David Stem, David N. Weiss',
#         'director': 'Andrew AdamsonKelly AsburyConrad Vernon',
#         'distributor': ' DreamWorks',
#         'duration': ' 1 hrs. 33 min.',
#         'genre': ' Animation',
#         'gross_domestic': '$441,226,247',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMDJhMGRjN2QtNDUxYy00NGM3LThjNGQtMmZiZTRhNjM4YzUxL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG',
#         'release_date': ' May 19, 2004',
#         'sub_genres': 'Animation, Animation - Computer, Animation - Fantasy',
#         'title': 'Shrek 2'},
#     {   'budget': ' $94 million',
#         'cast': 'Philippa Boyens',
#         'director': 'Peter Jackson',
#         'distributor': ' New Line',
#         'duration': ' 3 hrs. 20 min.',
#         'genre': ' Fantasy',
#         'gross_domestic': '$377,027,325',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BYWY1ZWQ5YjMtMDE0MS00NWIzLWE1M2YtODYzYTk2OTNlYWZmXkEyXkFqcGdeQXVyNDUyOTg3Njg@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' December 17, 2003',
#         'sub_genres': 'Fantasy - Live Action, Sword and Sorcery',
#         'title': 'Return of the King'},
#     {   'budget': ' $139 million',
#         'cast': 'David Koepp',
#         'director': 'Sam Raimi',
#         'distributor': ' Sony / Columbia',
#         'duration': ' 2 hrs. 1 min.',
#         'genre': ' Action / Adventure',
#         'gross_domestic': '$403,706,375',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BZDEyN2NhMjgtMjdhNi00MmNlLWE5YTgtZGE4MzNjMTRlMGEwXkEyXkFqcGdeQXVyNDUyOTg3Njg@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' May 3, 2002',
#         'sub_genres': 'Comic Book Adaptation, Superhero, Superhero - Origin',
#         'title': 'Spider-Man'},
#     {   'budget': ' $125 million',
#         'cast': 'Steve Kloves',
#         'director': 'Chris Columbus',
#         'distributor': ' Warner Bros.',
#         'duration': ' 2 hrs. 33 min.',
#         'genre': ' Fantasy',
#         'gross_domestic': '$317,575,550',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BNjQ3NWNlNmQtMTE5ZS00MDdmLTlkZjUtZTBlM2UxMGFiMTU3XkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG',
#         'release_date': ' November 16, 2001',
#         'sub_genres': "Dragon - Supporting Role, Family - Children's Book "
#                       'Adaptation, Fantasy - Live Action, School - Prep / '
#                       'Boarding / Catholic, Young-Adult Book Adaptations',
#         'title': "Harry Potter / Sorcerer's Stone"},
#     {   'budget': ' $123 million',
#         'cast': 'Jim Carrey, Anthony Hopkins*',
#         'director': 'Ron Howard',
#         'distributor': ' Universal',
#         'duration': ' 1 hrs. 44 min.',
#         'genre': ' Family Comedy',
#         'gross_domestic': '$260,044,825',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BNWNiNTczNzEtMjQyZC00MjFmLTkzMDMtODk4ZGMyZmE0N2E4XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG',
#         'release_date': ' November 17, 2000',
#         'sub_genres': "Christmas, Family - Children's Book Adaptation",
#         'title': 'The Grinch'},
#     {   'budget': ' $115 million',
#         'cast': 'George Lucas',
#         'director': 'George Lucas',
#         'distributor': ' Fox',
#         'duration': ' 2 hrs. 13 min.',
#         'genre': ' Sci-Fi Fantasy',
#         'gross_domestic': '$431,088,295',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BYTRhNjcwNWQtMGJmMi00NmQyLWE2YzItODVmMTdjNWI0ZDA2XkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG',
#         'release_date': ' May 19, 1999',
#         'sub_genres': 'Prequel, Sci-Fi - Adventure',
#         'title': 'The Phantom Menace'},
#     {   'budget': ' $70 million',
#         'cast': 'Tom Hanks, Edward Burns, Vin Diesel, Giovanni Ribisi, Matt '
#                 'Damon, Paul Giamatti*, Bryan Cranston*',
#         'director': 'Steven Spielberg',
#         'distributor': ' DreamWorks',
#         'duration': ' 2 hrs. 50 min.',
#         'genre': ' War',
#         'gross_domestic': '$216,540,909',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BZjhkMDM4MWItZTVjOC00ZDRhLThmYTAtM2I5NzBmNmNlMzI1XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' R',
#         'release_date': ' July 24, 1998',
#         'sub_genres': 'Drama - Summer, War - World War 2',
#         'title': 'Saving Private Ryan'},
#     {   'budget': ' $200 million',
#         'cast': 'James Cameron',
#         'director': 'James Cameron',
#         'distributor': ' Paramount',
#         'duration': ' 3 hrs. 14 min.',
#         'genre': ' Romance',
#         'gross_domestic': '$600,788,188',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMDdmZGU3NDQtY2E5My00ZTliLWIzOTUtMTY4ZGI1YjdiNjk3XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' December 19, 1997',
#         'sub_genres': 'Disaster, Romantic Drama',
#         'title': 'Titanic'},
#     {   'budget': ' $75 million',
#         'cast': 'Dean Devlin',
#         'director': 'Roland Emmerich',
#         'distributor': ' Fox',
#         'duration': ' 2 hrs. 33 min.',
#         'genre': ' Sci-Fi Action',
#         'gross_domestic': '$306,169,268',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMGQwNDNkMmItYWY1Yy00YTZmLWE5OTAtODU0MGZmMzQ1NDdkXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' July 3, 1996',
#         'sub_genres': 'Disaster, President, Sci-Fi - Alien Invasion',
#         'title': 'Independence Day'},
#     {   'budget': ' N/A',
#         'cast': 'Joel Cohen, Pete Docter, John Lasseter, Alec Sokolow, Andrew '
#                 'Stanton, Joss Whedon',
#         'director': 'John Lasseter',
#         'distributor': ' Buena Vista',
#         'duration': ' 1 hrs. 21 min.',
#         'genre': ' Animation',
#         'gross_domestic': '$191,796,233',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMDU2ZWJlMjktMTRhMy00ZTA5LWEzNDgtYmNmZTEwZTViZWJkXkEyXkFqcGdeQXVyNDQ2OTk4MzI@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' G',
#         'release_date': ' November 22, 1995',
#         'sub_genres': 'Animation, Animation - Computer, Toys Come to Life',
#         'title': 'Toy Story'},
#     {   'budget': ' $55 million',
#         'cast': 'Eric Roth',
#         'director': 'Robert Zemeckis',
#         'distributor': ' Paramount',
#         'duration': ' 2 hrs. 21 min.',
#         'genre': ' Comedy / Drama',
#         'gross_domestic': '$329,694,499',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BNWIwODRlZTUtY2U3ZS00Yzg1LWJhNzYtMmZiYmEyNmU1NjMzXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' July 6, 1994',
#         'sub_genres': 'Drama - Summer, Sports - Football (Featured)',
#         'title': 'Forrest Gump'},
#     {   'budget': ' $63 million',
#         'cast': 'David Koepp',
#         'director': 'Steven Spielberg',
#         'distributor': ' Universal',
#         'duration': ' 2 hrs. 7 min.',
#         'genre': ' Sci-Fi Horror',
#         'gross_domestic': '$357,067,947',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMjM2MDgxMDg0Nl5BMl5BanBnXkFtZTgwNTM2OTM5NDE@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' June 11, 1993',
#         'sub_genres': 'Creature Feature, Dinosaur, Sci-Fi - Adventure, Sci-Fi '
#                       '- Based on Book',
#         'title': 'Jurassic Park'},
#     {   'budget': ' $28 million',
#         'cast': 'Robin Williams',
#         'director': 'Ted ElliottTerry RossioChris Sanders (story)',
#         'distributor': ' Buena Vista',
#         'duration': ' 1 hrs. 30 min.',
#         'genre': ' Animation',
#         'gross_domestic': '$217,350,219',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BY2Q2NDI1MjUtM2Q5ZS00MTFlLWJiYWEtNTZmNjQ3OGJkZDgxXkEyXkFqcGdeQXVyNTI4MjkwNjA@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' G',
#         'release_date': ' November 13, 1992',
#         'sub_genres': 'Animation, Animation - Fantasy, Travelogue - Middle '
#                       'East',
#         'title': 'Aladdin'},
#     {   'budget': ' $102 million',
#         'cast': 'James Cameron',
#         'director': 'James Cameron',
#         'distributor': ' TriStar',
#         'duration': ' 2 hrs. 17 min.',
#         'genre': ' Sci-Fi Action',
#         'gross_domestic': '$204,843,345',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMGU2NzRmZjUtOGUxYS00ZjdjLWEwZWItY2NlM2JhNjkxNTFmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' R',
#         'release_date': ' July 3, 1991',
#         'sub_genres': 'Action Heroine, Cyborg / Android / Robot, Man vs. '
#                       'Machine, Sci-Fi Chase, Time Travel',
#         'title': 'Terminator 2'},
#     {   'budget': ' $18 million',
#         'cast': 'John Hughes',
#         'director': 'Chris Columbus',
#         'distributor': ' Fox',
#         'duration': ' 1 hrs. 45 min.',
#         'genre': ' Family Comedy',
#         'gross_domestic': '$285,761,243',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMzFkM2YwOTQtYzk2Mi00N2VlLWE3NTItN2YwNDg1YmY0ZDNmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG',
#         'release_date': ' November 16, 1990',
#         'sub_genres': 'Christmas, Christmas - Setting Only',
#         'title': 'Home Alone'},
#     {   'budget': ' $35 million',
#         'cast': 'Jack Nicholson, Michael Keaton, Kim Basinger',
#         'director': 'Tim Burton',
#         'distributor': ' Warner Bros.',
#         'duration': ' 2 hrs. 6 min.',
#         'genre': ' Action / Adventure',
#         'gross_domestic': '$251,188,924',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMTYwNjAyODIyMF5BMl5BanBnXkFtZTYwNDMwMDk2._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG-13',
#         'release_date': ' June 23, 1989',
#         'sub_genres': 'Comic Book Adaptation, Superhero, Superhero - Origin',
#         'title': 'Batman'},
#     {   'budget': ' $25 million',
#         'cast': 'Dustin Hoffman, Tom Cruise, Bonnie Hunt*',
#         'director': 'Barry Levinson',
#         'distributor': ' MGM',
#         'duration': ' 2 hrs. 13 min.',
#         'genre': ' Drama',
#         'gross_domestic': '$172,825,435',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMzVjNzI4NzYtMjE4NS00M2IzLWFkOWMtOTYwMWUzN2ZlNGVjL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' R',
#         'release_date': ' December 16, 1988',
#         'title': 'Rain Man'},
#     {   'budget': ' $11 million',
#         'cast': 'Adam Greenberg',
#         'director': 'Ted Field',
#         'distributor': ' Buena Vista',
#         'duration': ' 1 hrs. 42 min.',
#         'genre': ' Comedy',
#         'gross_domestic': '$167,780,960',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMjRkNjMyNWUtMjNjYi00M2FkLTk2ZDYtYjVkMGRmZjY2MzA4XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG',
#         'release_date': ' November 25, 1987',
#         'sub_genres': 'Comedy - Fish-Out-of-Water Father, Remake - French',
#         'title': 'Three Men and a Baby'},
#     {   'budget': ' N/A',
#         'cast': 'Tom Cruise, Val Kilmer, Meg Ryan, Tim Robbins*',
#         'director': 'Tony Scott',
#         'distributor': ' Paramount',
#         'duration': ' 1 hrs. 50 min.',
#         'genre': ' Action Drama',
#         'gross_domestic': '$176,781,728',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BZjQxYTA3ODItNzgxMy00N2Y2LWJlZGMtMTRlM2JkZjI1ZDhhXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG',
#         'release_date': ' May 16, 1986',
#         'sub_genres': 'Pilot / Aircraft',
#         'title': 'Top Gun'},
#     {   'budget': ' $19 million',
#         'cast': 'Kathleen Kennedy, Frank Marshall, Steven Spielberg',
#         'director': 'Robert Zemeckis',
#         'distributor': ' Universal',
#         'duration': ' 1 hrs. 51 min.',
#         'genre': ' Sci-Fi Adventure',
#         'gross_domestic': '$210,609,762',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BZmU0M2Y1OGUtZjIxNi00ZjBkLTg1MjgtOWIyNThiZWIwYjRiXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG',
#         'release_date': ' July 3, 1985',
#         'sub_genres': 'Sci-Fi - Adventure, Time Travel',
#         'title': 'Back to the Future'},
#     {   'budget': ' N/A',
#         'cast': 'Eddie Murphy, Damon Wayans*',
#         'director': 'Martin Brest',
#         'distributor': ' Paramount',
#         'duration': ' 1 hrs. 45 min.',
#         'genre': ' Action Comedy',
#         'gross_domestic': '$234,760,478',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BN2MyZDE0YjAtNWFjYy00MWRlLTk3MTktMzY3ZDVhNTJkZTlmXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' R',
#         'release_date': ' December 5, 1984',
#         'title': 'Beverly Hills Cop'},
#     {   'budget': ' $32.5 million',
#         'cast': 'Tony Cox*, Mark Hamill, Harrison Ford, Carrie Fisher, Anthony '
#                 'Daniels, Peter Mayhew, Ian McDiarmid, Frank Oz*',
#         'director': 'Lawrence KasdanGeorge Lucas',
#         'distributor': ' Fox',
#         'duration': ' 2 hrs. 14 min.',
#         'genre': ' Sci-Fi Fantasy',
#         'gross_domestic': '$252,583,617',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BOWZlMjFiYzgtMTUzNC00Y2IzLTk1NTMtZmNhMTczNTk0ODk1XkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG',
#         'release_date': ' May 25, 1983',
#         'sub_genres': 'Sci-Fi - Adventure',
#         'title': 'Return of the Jedi'},
#     {   'budget': ' $10.5 million',
#         'cast': 'Drew Barrymore',
#         'director': 'Steven Spielberg',
#         'distributor': ' Universal',
#         'duration': ' 1 hrs. 57 min.',
#         'genre': ' Family Adventure',
#         'gross_domestic': '$359,197,037',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMTQ2ODFlMDAtNzdhOC00ZDYzLWE3YTMtNDU4ZGFmZmJmYTczXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG',
#         'release_date': ' June 11, 1982',
#         'sub_genres': 'Sci-Fi - Adventure',
#         'title': 'E.T.'},
#     {   'budget': ' $18 million',
#         'cast': 'Lawrence Kasdan, George Lucas',
#         'director': 'Steven Spielberg',
#         'distributor': ' Paramount',
#         'duration': ' 1 hrs. 55 min.',
#         'genre': ' Period Adventure',
#         'gross_domestic': '$212,222,025',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BMjA0ODEzMTc1Nl5BMl5BanBnXkFtZTcwODM2MjAxNA@@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG',
#         'release_date': ' June 12, 1981',
#         'sub_genres': 'Adventure - Period, Travelogue - Middle East, Treasure '
#                       'Hunt',
#         'title': 'Raiders / Lost Ark'},
#     {   'budget': ' $18 million',
#         'cast': 'Lawrence Kasdan, George Lucas',
#         'director': 'Irvin Kershner',
#         'distributor': ' Fox',
#         'duration': ' 2 hrs. 9 min.',
#         'genre': ' Sci-Fi Fantasy',
#         'gross_domestic': '$209,398,025',
#         'gross_foreign': None,
#         'gross_worldwide': None,
#         'image': 'https://ia.media-imdb.com/images/M/MV5BYmU1NDRjNDgtMzhiMi00NjZmLTg5NGItZDNiZjU5NTU4OTE0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY222_CR0,0,150,222_AL.jpg',
#         'rating': ' PG',
#         'release_date': ' May 21, 1980',
#         'sub_genres': 'Sci-Fi - Adventure',
#         'title': 'The Empire Strikes Back'}]

# %%
films[7:]
# Out:
# [{'budget': ' N/A',
#   'cast': 'Steve Kloves',
#   'director': 'David Yates',
#   'distributor': ' Warner Bros.',
#   'duration': ' 2 hrs. 10 min.',
#   'genre': ' Fantasy',
#   'gross_domestic': '$381,011,219',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BMjIyZGU4YzUtNDkzYi00ZDRhLTljYzctYTMxMDQ4M2E0Y2YxXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG-13',
#   'release_date': ' July 15, 2011',
#   'sub_genres': "3D, Dragon - Supporting Role, Family - Children's Book Adaptation, Fantasy - Live Action, IMAX (Feature-length), Young-Adult Book Adaptations",
#   'title': 'Harry Potter / Deathly Hallows (P2)'},
#  {'budget': ' $200 million',
#   'cast': 'Michael Arndt, John Lasseter, Andrew Stanton, Lee Unkrich',
#   'director': 'Lee Unkrich',
#   'distributor': ' Buena Vista',
#   'duration': ' 1 hrs. 43 min.',
#   'genre': ' Animation',
#   'gross_domestic': '$415,004,880',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BMTgxOTY4Mjc0MF5BMl5BanBnXkFtZTcwNTA4MDQyMw@@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' G',
#   'release_date': ' June 18, 2010',
#   'sub_genres': '3D, Animation, Animation - Computer, IMAX (Feature-length), Toys Come to Life',
#   'title': 'Toy Story 3'},
#  {'budget': ' $237 million',
#   'cast': 'James Cameron',
#   'director': 'James Cameron',
#   'distributor': ' Fox',
#   'duration': ' 2 hrs. 40 min.',
#   'genre': ' Sci-Fi Adventure',
#   'gross_domestic': '$749,766,139',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BMTYwOTEwNjAzMl5BMl5BanBnXkFtZTcwODc5MTUwMw@@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG-13',
#   'release_date': ' December 18, 2009',
#   'sub_genres': '3D, CGI Star, Disability - Paraplegic / Quadriplegic, Environmentalist, IMAX (Feature-length), Sci-Fi - Adventure',
#   'title': 'Avatar'},
#  {'budget': ' $185 million',
#   'cast': 'David S. Goyer, Christopher Nolan',
#   'director': 'Christopher Nolan',
#   'distributor': ' Warner Bros.',
#   'duration': ' 2 hrs. 30 min.',
#   'genre': ' Action / Adventure',
#   'gross_domestic': '$533,345,358',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG-13',
#   'release_date': ' July 18, 2008',
#   'sub_genres': 'Comic Book Adaptation, IMAX (Feature-length), Superhero',
#   'title': 'The Dark Knight'},
#  {'budget': ' $258 million',
#   'cast': 'Alvin Sargent',
#   'director': 'Sam Raimi',
#   'distributor': ' Sony / Columbia',
#   'duration': ' 2 hrs. 20 min.',
#   'genre': ' Action / Adventure',
#   'gross_domestic': '$336,530,303',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BYTk3MDljOWQtNGI2My00OTEzLTlhYjQtOTQ4ODM2MzUwY2IwXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG-13',
#   'release_date': ' May 4, 2007',
#   'sub_genres': 'Comic Book Adaptation, IMAX (Feature-length), Superhero',
#   'title': 'Spider-Man 3'},
#  {'budget': ' $225 million',
#   'cast': 'Stuart Beattie, Ted Elliott, Terry Rossio',
#   'director': 'Gore Verbinski',
#   'distributor': ' Buena Vista',
#   'duration': ' 2 hrs. 31 min.',
#   'genre': ' Period Adventure',
#   'gross_domestic': '$423,315,812',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BMTcwODc1MTMxM15BMl5BanBnXkFtZTYwMDg1NzY3._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG-13',
#   'release_date': ' July 7, 2006',
#   'sub_genres': 'Adventure - Period, Pirate, Swashbuckler, Treasure Hunt',
#   'title': "Dead Man's Chest"},
#  {'budget': ' $113 million',
#   'cast': 'George Lucas',
#   'director': 'George Lucas',
#   'distributor': ' Fox',
#   'duration': ' 2 hrs. 26 min.',
#   'genre': ' Sci-Fi Fantasy',
#   'gross_domestic': '$380,270,577',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BNTc4MTc3NTQ5OF5BMl5BanBnXkFtZTcwOTg0NjI4NA@@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG-13',
#   'release_date': ' May 19, 2005',
#   'sub_genres': 'Prequel, Sci-Fi - Adventure',
#   'title': 'Revenge of the Sith'},
#  {'budget': ' $150 million',
#   'cast': 'J. David Stem, David N. Weiss',
#   'director': 'Andrew AdamsonKelly AsburyConrad Vernon',
#   'distributor': ' DreamWorks',
#   'duration': ' 1 hrs. 33 min.',
#   'genre': ' Animation',
#   'gross_domestic': '$441,226,247',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BMDJhMGRjN2QtNDUxYy00NGM3LThjNGQtMmZiZTRhNjM4YzUxL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG',
#   'release_date': ' May 19, 2004',
#   'sub_genres': 'Animation, Animation - Computer, Animation - Fantasy',
#   'title': 'Shrek 2'},
#  {'budget': ' $94 million',
#   'cast': 'Philippa Boyens',
#   'director': 'Peter Jackson',
#   'distributor': ' New Line',
#   'duration': ' 3 hrs. 20 min.',
#   'genre': ' Fantasy',
#   'gross_domestic': '$377,027,325',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BYWY1ZWQ5YjMtMDE0MS00NWIzLWE1M2YtODYzYTk2OTNlYWZmXkEyXkFqcGdeQXVyNDUyOTg3Njg@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG-13',
#   'release_date': ' December 17, 2003',
#   'sub_genres': 'Fantasy - Live Action, Sword and Sorcery',
#   'title': 'Return of the King'},
#  {'budget': ' $139 million',
#   'cast': 'David Koepp',
#   'director': 'Sam Raimi',
#   'distributor': ' Sony / Columbia',
#   'duration': ' 2 hrs. 1 min.',
#   'genre': ' Action / Adventure',
#   'gross_domestic': '$403,706,375',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BZDEyN2NhMjgtMjdhNi00MmNlLWE5YTgtZGE4MzNjMTRlMGEwXkEyXkFqcGdeQXVyNDUyOTg3Njg@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG-13',
#   'release_date': ' May 3, 2002',
#   'sub_genres': 'Comic Book Adaptation, Superhero, Superhero - Origin',
#   'title': 'Spider-Man'},
#  {'budget': ' $125 million',
#   'cast': 'Steve Kloves',
#   'director': 'Chris Columbus',
#   'distributor': ' Warner Bros.',
#   'duration': ' 2 hrs. 33 min.',
#   'genre': ' Fantasy',
#   'gross_domestic': '$317,575,550',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BNjQ3NWNlNmQtMTE5ZS00MDdmLTlkZjUtZTBlM2UxMGFiMTU3XkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG',
#   'release_date': ' November 16, 2001',
#   'sub_genres': "Dragon - Supporting Role, Family - Children's Book Adaptation, Fantasy - Live Action, School - Prep / Boarding / Catholic, Young-Adult Book Adaptations",
#   'title': "Harry Potter / Sorcerer's Stone"},
#  {'budget': ' $123 million',
#   'cast': 'Jim Carrey, Anthony Hopkins*',
#   'director': 'Ron Howard',
#   'distributor': ' Universal',
#   'duration': ' 1 hrs. 44 min.',
#   'genre': ' Family Comedy',
#   'gross_domestic': '$260,044,825',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BNWNiNTczNzEtMjQyZC00MjFmLTkzMDMtODk4ZGMyZmE0N2E4XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG',
#   'release_date': ' November 17, 2000',
#   'sub_genres': "Christmas, Family - Children's Book Adaptation",
#   'title': 'The Grinch'},
#  {'budget': ' $115 million',
#   'cast': 'George Lucas',
#   'director': 'George Lucas',
#   'distributor': ' Fox',
#   'duration': ' 2 hrs. 13 min.',
#   'genre': ' Sci-Fi Fantasy',
#   'gross_domestic': '$431,088,295',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BYTRhNjcwNWQtMGJmMi00NmQyLWE2YzItODVmMTdjNWI0ZDA2XkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG',
#   'release_date': ' May 19, 1999',
#   'sub_genres': 'Prequel, Sci-Fi - Adventure',
#   'title': 'The Phantom Menace'},
#  {'budget': ' $70 million',
#   'cast': 'Tom Hanks, Edward Burns, Vin Diesel, Giovanni Ribisi, Matt Damon, Paul Giamatti*, Bryan Cranston*',
#   'director': 'Steven Spielberg',
#   'distributor': ' DreamWorks',
#   'duration': ' 2 hrs. 50 min.',
#   'genre': ' War',
#   'gross_domestic': '$216,540,909',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BZjhkMDM4MWItZTVjOC00ZDRhLThmYTAtM2I5NzBmNmNlMzI1XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' R',
#   'release_date': ' July 24, 1998',
#   'sub_genres': 'Drama - Summer, War - World War 2',
#   'title': 'Saving Private Ryan'},
#  {'budget': ' $200 million',
#   'cast': 'James Cameron',
#   'director': 'James Cameron',
#   'distributor': ' Paramount',
#   'duration': ' 3 hrs. 14 min.',
#   'genre': ' Romance',
#   'gross_domestic': '$600,788,188',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BMDdmZGU3NDQtY2E5My00ZTliLWIzOTUtMTY4ZGI1YjdiNjk3XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG-13',
#   'release_date': ' December 19, 1997',
#   'sub_genres': 'Disaster, Romantic Drama',
#   'title': 'Titanic'},
#  {'budget': ' $75 million',
#   'cast': 'Dean Devlin',
#   'director': 'Roland Emmerich',
#   'distributor': ' Fox',
#   'duration': ' 2 hrs. 33 min.',
#   'genre': ' Sci-Fi Action',
#   'gross_domestic': '$306,169,268',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BMGQwNDNkMmItYWY1Yy00YTZmLWE5OTAtODU0MGZmMzQ1NDdkXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG-13',
#   'release_date': ' July 3, 1996',
#   'sub_genres': 'Disaster, President, Sci-Fi - Alien Invasion',
#   'title': 'Independence Day'},
#  {'budget': ' N/A',
#   'cast': 'Joel Cohen, Pete Docter, John Lasseter, Alec Sokolow, Andrew Stanton, Joss Whedon',
#   'director': 'John Lasseter',
#   'distributor': ' Buena Vista',
#   'duration': ' 1 hrs. 21 min.',
#   'genre': ' Animation',
#   'gross_domestic': '$191,796,233',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BMDU2ZWJlMjktMTRhMy00ZTA5LWEzNDgtYmNmZTEwZTViZWJkXkEyXkFqcGdeQXVyNDQ2OTk4MzI@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' G',
#   'release_date': ' November 22, 1995',
#   'sub_genres': 'Animation, Animation - Computer, Toys Come to Life',
#   'title': 'Toy Story'},
#  {'budget': ' $55 million',
#   'cast': 'Eric Roth',
#   'director': 'Robert Zemeckis',
#   'distributor': ' Paramount',
#   'duration': ' 2 hrs. 21 min.',
#   'genre': ' Comedy / Drama',
#   'gross_domestic': '$329,694,499',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BNWIwODRlZTUtY2U3ZS00Yzg1LWJhNzYtMmZiYmEyNmU1NjMzXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG-13',
#   'release_date': ' July 6, 1994',
#   'sub_genres': 'Drama - Summer, Sports - Football (Featured)',
#   'title': 'Forrest Gump'},
#  {'budget': ' $63 million',
#   'cast': 'David Koepp',
#   'director': 'Steven Spielberg',
#   'distributor': ' Universal',
#   'duration': ' 2 hrs. 7 min.',
#   'genre': ' Sci-Fi Horror',
#   'gross_domestic': '$357,067,947',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BMjM2MDgxMDg0Nl5BMl5BanBnXkFtZTgwNTM2OTM5NDE@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG-13',
#   'release_date': ' June 11, 1993',
#   'sub_genres': 'Creature Feature, Dinosaur, Sci-Fi - Adventure, Sci-Fi - Based on Book',
#   'title': 'Jurassic Park'},
#  {'budget': ' $28 million',
#   'cast': 'Robin Williams',
#   'director': 'Ted ElliottTerry RossioChris Sanders (story)',
#   'distributor': ' Buena Vista',
#   'duration': ' 1 hrs. 30 min.',
#   'genre': ' Animation',
#   'gross_domestic': '$217,350,219',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BY2Q2NDI1MjUtM2Q5ZS00MTFlLWJiYWEtNTZmNjQ3OGJkZDgxXkEyXkFqcGdeQXVyNTI4MjkwNjA@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' G',
#   'release_date': ' November 13, 1992',
#   'sub_genres': 'Animation, Animation - Fantasy, Travelogue - Middle East',
#   'title': 'Aladdin'},
#  {'budget': ' $102 million',
#   'cast': 'James Cameron',
#   'director': 'James Cameron',
#   'distributor': ' TriStar',
#   'duration': ' 2 hrs. 17 min.',
#   'genre': ' Sci-Fi Action',
#   'gross_domestic': '$204,843,345',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BMGU2NzRmZjUtOGUxYS00ZjdjLWEwZWItY2NlM2JhNjkxNTFmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' R',
#   'release_date': ' July 3, 1991',
#   'sub_genres': 'Action Heroine, Cyborg / Android / Robot, Man vs. Machine, Sci-Fi Chase, Time Travel',
#   'title': 'Terminator 2'},
#  {'budget': ' $18 million',
#   'cast': 'John Hughes',
#   'director': 'Chris Columbus',
#   'distributor': ' Fox',
#   'duration': ' 1 hrs. 45 min.',
#   'genre': ' Family Comedy',
#   'gross_domestic': '$285,761,243',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BMzFkM2YwOTQtYzk2Mi00N2VlLWE3NTItN2YwNDg1YmY0ZDNmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG',
#   'release_date': ' November 16, 1990',
#   'sub_genres': 'Christmas, Christmas - Setting Only',
#   'title': 'Home Alone'},
#  {'budget': ' $35 million',
#   'cast': 'Jack Nicholson, Michael Keaton, Kim Basinger',
#   'director': 'Tim Burton',
#   'distributor': ' Warner Bros.',
#   'duration': ' 2 hrs. 6 min.',
#   'genre': ' Action / Adventure',
#   'gross_domestic': '$251,188,924',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BMTYwNjAyODIyMF5BMl5BanBnXkFtZTYwNDMwMDk2._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG-13',
#   'release_date': ' June 23, 1989',
#   'sub_genres': 'Comic Book Adaptation, Superhero, Superhero - Origin',
#   'title': 'Batman'},
#  {'budget': ' $25 million',
#   'cast': 'Dustin Hoffman, Tom Cruise, Bonnie Hunt*',
#   'director': 'Barry Levinson',
#   'distributor': ' MGM',
#   'duration': ' 2 hrs. 13 min.',
#   'genre': ' Drama',
#   'gross_domestic': '$172,825,435',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BMzVjNzI4NzYtMjE4NS00M2IzLWFkOWMtOTYwMWUzN2ZlNGVjL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' R',
#   'release_date': ' December 16, 1988',
#   'title': 'Rain Man'},
#  {'budget': ' $11 million',
#   'cast': 'Adam Greenberg',
#   'director': 'Ted Field',
#   'distributor': ' Buena Vista',
#   'duration': ' 1 hrs. 42 min.',
#   'genre': ' Comedy',
#   'gross_domestic': '$167,780,960',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BMjRkNjMyNWUtMjNjYi00M2FkLTk2ZDYtYjVkMGRmZjY2MzA4XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG',
#   'release_date': ' November 25, 1987',
#   'sub_genres': 'Comedy - Fish-Out-of-Water Father, Remake - French',
#   'title': 'Three Men and a Baby'},
#  {'budget': ' N/A',
#   'cast': 'Tom Cruise, Val Kilmer, Meg Ryan, Tim Robbins*',
#   'director': 'Tony Scott',
#   'distributor': ' Paramount',
#   'duration': ' 1 hrs. 50 min.',
#   'genre': ' Action Drama',
#   'gross_domestic': '$176,781,728',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BZjQxYTA3ODItNzgxMy00N2Y2LWJlZGMtMTRlM2JkZjI1ZDhhXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG',
#   'release_date': ' May 16, 1986',
#   'sub_genres': 'Pilot / Aircraft',
#   'title': 'Top Gun'},
#  {'budget': ' $19 million',
#   'cast': 'Kathleen Kennedy, Frank Marshall, Steven Spielberg',
#   'director': 'Robert Zemeckis',
#   'distributor': ' Universal',
#   'duration': ' 1 hrs. 51 min.',
#   'genre': ' Sci-Fi Adventure',
#   'gross_domestic': '$210,609,762',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BZmU0M2Y1OGUtZjIxNi00ZjBkLTg1MjgtOWIyNThiZWIwYjRiXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG',
#   'release_date': ' July 3, 1985',
#   'sub_genres': 'Sci-Fi - Adventure, Time Travel',
#   'title': 'Back to the Future'},
#  {'budget': ' N/A',
#   'cast': 'Eddie Murphy, Damon Wayans*',
#   'director': 'Martin Brest',
#   'distributor': ' Paramount',
#   'duration': ' 1 hrs. 45 min.',
#   'genre': ' Action Comedy',
#   'gross_domestic': '$234,760,478',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BN2MyZDE0YjAtNWFjYy00MWRlLTk3MTktMzY3ZDVhNTJkZTlmXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' R',
#   'release_date': ' December 5, 1984',
#   'title': 'Beverly Hills Cop'},
#  {'budget': ' $32.5 million',
#   'cast': 'Tony Cox*, Mark Hamill, Harrison Ford, Carrie Fisher, Anthony Daniels, Peter Mayhew, Ian McDiarmid, Frank Oz*',
#   'director': 'Lawrence KasdanGeorge Lucas',
#   'distributor': ' Fox',
#   'duration': ' 2 hrs. 14 min.',
#   'genre': ' Sci-Fi Fantasy',
#   'gross_domestic': '$252,583,617',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BOWZlMjFiYzgtMTUzNC00Y2IzLTk1NTMtZmNhMTczNTk0ODk1XkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG',
#   'release_date': ' May 25, 1983',
#   'sub_genres': 'Sci-Fi - Adventure',
#   'title': 'Return of the Jedi'},
#  {'budget': ' $10.5 million',
#   'cast': 'Drew Barrymore',
#   'director': 'Steven Spielberg',
#   'distributor': ' Universal',
#   'duration': ' 1 hrs. 57 min.',
#   'genre': ' Family Adventure',
#   'gross_domestic': '$359,197,037',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BMTQ2ODFlMDAtNzdhOC00ZDYzLWE3YTMtNDU4ZGFmZmJmYTczXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG',
#   'release_date': ' June 11, 1982',
#   'sub_genres': 'Sci-Fi - Adventure',
#   'title': 'E.T.'},
#  {'budget': ' $18 million',
#   'cast': 'Lawrence Kasdan, George Lucas',
#   'director': 'Steven Spielberg',
#   'distributor': ' Paramount',
#   'duration': ' 1 hrs. 55 min.',
#   'genre': ' Period Adventure',
#   'gross_domestic': '$212,222,025',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BMjA0ODEzMTc1Nl5BMl5BanBnXkFtZTcwODM2MjAxNA@@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG',
#   'release_date': ' June 12, 1981',
#   'sub_genres': 'Adventure - Period, Travelogue - Middle East, Treasure Hunt',
#   'title': 'Raiders / Lost Ark'},
#  {'budget': ' $18 million',
#   'cast': 'Lawrence Kasdan, George Lucas',
#   'director': 'Irvin Kershner',
#   'distributor': ' Fox',
#   'duration': ' 2 hrs. 9 min.',
#   'genre': ' Sci-Fi Fantasy',
#   'gross_domestic': '$209,398,025',
#   'gross_foreign': None,
#   'gross_worldwide': None,
#   'image': 'https://ia.media-imdb.com/images/M/MV5BYmU1NDRjNDgtMzhiMi00NjZmLTg5NGItZDNiZjU5NTU4OTE0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY222_CR0,0,150,222_AL.jpg',
#   'rating': ' PG',
#   'release_date': ' May 21, 1980',
#   'sub_genres': 'Sci-Fi - Adventure',
#   'title': 'The Empire Strikes Back'}]

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException  
from selenium.webdriver.chrome.options import Options
import time
import os
import zipfile
from os import listdir
from os.path import isfile, join
from urllib.request import urlretrieve


chromedriver = "/Users/justinblinder/dev/drivers/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

'''instantiate a chrome options object so you can set the size and headless preference'''
chrome_options = Options()
chrome_options.add_argument("--headless")

''' add missing support for chrome "send_command"  to selenium webdriver (https://stackoverflow.com/a/47366981/190155)'''
#driver.command_executor._commands["send_command"] = ("POST", '/session/$sessionId/chromium/send_command')
#params = {'cmd': 'Page.setDownloadBehavior', 'params': {'behavior': 'allow', 'downloadPath': '/Users/justinblinder/Downloads/srt/'}}
#command_result = driver.execute("send_command", params)

#driver = webdriver.Chrome(chromedriver,chrome_options=chrome_options)
driver = webdriver.Chrome(chromedriver)
driver.get("https://subscene.com/")

# set wait time
driver.implicitly_wait(4)

# %%
'''Collect a download url for each film'''
# Chrome headless mode does not allow dowloading files
# Cannot curl file url because it's a cloudflare redirect

download_path = '/Users/justinblinder/Downloads/'
download_links = {}

'''Main subtitle search page'''
def search_film(film_title,year):
    form_input = driver.find_element_by_name("q")
    form_input.send_keys(film_title)
    '''Search for film'''
    form_input.send_keys(Keys.RETURN)
    get_filtered_film(film_title,year)

def parse_subtitle_section(film_title):
    try:
        return driver.find_element_by_xpath('//h2[text()="Exact"]/following-sibling::ul/descendant::div[@class="title"]/descendant::a')
    except NoSuchElementException:
        print("FILM WAS NOT EXACT",film_title)    
    try:
        print("FILM WAS CLOSE",film_title)
        
        link = driver.find_element_by_xpath('//h2[text()="Close"]/following-sibling::ul/descendant::div[@class="title"]/descendant::a')
    except NoSuchElementException:
        print("none")
    try:
        print("FILM WAS POPULAR",film_title)    
        return driver.find_element_by_xpath('//h2[text()="Popular"]/following-sibling::ul/descendant::div[@class="title"]/descendant::a')
    except NoSuchElementException:
        print("none")

def parse_subtitle_section_list(link,film_title,year):
    desired_link = None
    for i,li in enumerate(link):
        a_tag =  li.find_element_by_xpath('div[@class="title"]/descendant::a')
        li_title = a_tag.text.lower().replace(' ','-')
        b_missing = False
        if film_title not in li_title: 
            if year in li_title:
                desired_link = a_tag
                break
    print(desired_link)
    print(desired_link.get_attribute('href'))
    return desired_link

def parse_subtitle_section_test(film_title,year):
    try:
        return driver.find_element_by_xpath('//h2[text()="Exact"]/following-sibling::ul/descendant::div[@class="title"]/descendant::a')
    except NoSuchElementException:
        print("FILM WAS NOT EXACT",film_title)    
    
    try:
        print("FILM WAS CLOSE",film_title)
        film_list = driver.find_elements_by_xpath('//h2[text()="Popular"]/following-sibling::ul/li')
        link = parse_subtitle_section_list(film_list,film_title,year)
        return link
    except NoSuchElementException:
        print("none")

    try:
        print("FILM WAS POPULAR",film_title)    
        film_list = driver.find_element_by_xpath('//h2[text()="Popular"]/following-sibling::ul/descendant::div[@class="title"]/descendant::a')
        link = parse_subtitle_section_list(film_list,film_title,year)
        return link
    except NoSuchElementException:
        print("none")
    
def get_filtered_film(film_title,year):
    '''Similar film list page'''
    link = parse_subtitle_section_test(film_title,year)
    link.click()
    search_subtitles(film_title)


def check_exists_by_xpath(el,xpath):
    try:
        el.find_element_by_xpath(xpath)
    except NoSuchElementException:
        return False
    return True

'''Individual film subtitle list page'''

"""Find all engish subtitles that have a quality flag and aren't for hearing impaired"""
def search_subtitles(film_title):
    english_selector = '//a[contains(@href,"english")]'
    subtitle_links = driver.find_elements_by_xpath(english_selector)
    valid_links = []
    for link in subtitle_links:
        is_quality = check_exists_by_xpath(link,'span[contains(@class,"positive-icon")]')
        hearing_impaired_el = link.find_element_by_xpath('../following-sibling::td/following-sibling::td')     
        is_hearing_impaired = False if hearing_impaired_el.get_attribute('class') == "a40" else True
        if is_quality is True and is_hearing_impaired is False:
            valid_links.append(link)
    valid_links[0].click()
    get_download_link(film_title)
    
'''Find and click download link'''
def get_download_link(film_title):
    download_button = driver.find_element_by_id('downloadButton')
    # TODO: if link is zip then click, else go back to revious page and get a new one
    download_links[film_title] = download_button.get_attribute('href')
    download_button.click()
    unzip_file(film_title)

''' Locally unzip file'''
def unzip_file(film_title):
    time.sleep(2)
    for file in os.listdir(download_path):
        if file.endswith(".zip"):
            filename = os.path.join(download_path, file)
            unzip(filename,film_title)
    driver.get("https://subscene.com/")
    
''' Rename unzipped srt file / zip file and mov to seperate folders'''
def unzip(filename,film_title):
    # unzip file to srt dir
    zip_ref = zipfile.ZipFile(filename, 'r')
    zip_ref.extractall(download_path)
    zip_ref.close()

    # move zip to archive folder
    os.rename(filename, download_path+"archive/"+film_title.replace(' ','-').replace(':','')+'.zip')

    # get unzipped srt file
    srtfile = None
    for file in os.listdir(download_path):
        if file.endswith(".srt"):
            srtfile = os.path.join(download_path, file)
            os.rename(srtfile , download_path + "srt/"+film_title.replace(' ','-').replace(':','')+'.srt')



#films = ["almost famous", 'black panther','Star Wars: The Last Jedi','Rogue One']
for film in films[16:]:
    print(film)
    film_title = film['title']
    year = film['release_date'].split(',')[1].replace(' ', '')
    print(year)
    film['year'] = year #TODO: DO This ELSEWHERE
    search_film(film_title.replace('/',':'),film['year'])
# Out:
# {'title': 'Spider-Man', 'image': 'https://ia.media-imdb.com/images/M/MV5BZDEyN2NhMjgtMjdhNi00MmNlLWE5YTgtZGE4MzNjMTRlMGEwXkEyXkFqcGdeQXVyNDUyOTg3Njg@._V1_UY222_CR0,0,150,222_AL.jpg', 'distributor': ' Sony / Columbia', 'release_date': ' May 3, 2002', 'genre': ' Action / Adventure', 'duration': ' 2 hrs. 1 min.', 'rating': ' PG-13', 'budget': ' $139 million', 'gross_domestic': '$403,706,375', 'gross_foreign': None, 'gross_worldwide': None, 'director': 'Sam Raimi', 'cast': 'David Koepp', 'sub_genres': 'Comic Book Adaptation, Superhero, Superhero - Origin', 'year': '2002'}
# 2002
# FILM WAS NOT EXACT Spider-Man
# FILM WAS CLOSE Spider-Man
# <selenium.webdriver.remote.webelement.WebElement (session="8319d6fcc4b3ebba0e51dcdb5b841dcb", element="0.7461602894815549-17")>
# https://subscene.com/subtitles/spider-man-spiderman
# {'title': "Harry Potter / Sorcerer's Stone", 'image': 'https://ia.media-imdb.com/images/M/MV5BNjQ3NWNlNmQtMTE5ZS00MDdmLTlkZjUtZTBlM2UxMGFiMTU3XkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_UY222_CR0,0,150,222_AL.jpg', 'distributor': ' Warner Bros.', 'release_date': ' November 16, 2001', 'genre': ' Fantasy', 'duration': ' 2 hrs. 33 min.', 'rating': ' PG', 'budget': ' $125 million', 'gross_domestic': '$317,575,550', 'gross_foreign': None, 'gross_worldwide': None, 'director': 'Chris Columbus', 'cast': 'Steve Kloves', 'sub_genres': "Dragon - Supporting Role, Family - Children's Book Adaptation, Fantasy - Live Action, School - Prep / Boarding / Catholic, Young-Adult Book Adaptations"}
# 2001
# FILM WAS NOT EXACT Harry Potter : Sorcerer's Stone
# FILM WAS CLOSE Harry Potter : Sorcerer's Stone
# <selenium.webdriver.remote.webelement.WebElement (session="8319d6fcc4b3ebba0e51dcdb5b841dcb", element="0.49745895735810985-16")>
# https://subscene.com/subtitles/harry-potter-and-the-sorcerers-stone

# %%
link = driver.find_element_by_xpath('//h2[text()="Close"]/following-sibling::ul/descendant::div[@class="title"]/descendant::a')
link
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="7f151f456adef4f7b08696ed8e20e0d8", element="0.8731757835243388-1")>

# %%
link = driver.find_elements_by_xpath('//h2[text()="Popular"]/following-sibling::ul/li')
desired_link = None
for i,li in enumerate(link):
    xval =  li.find_element_by_xpath('div[@class="title"]/descendant::a')
    
    t = xval.text.lower().replace(' ','-')
    b_missing = False
    if "spider-man" not in t: 
        b_missing
    if '2002' in t:
        print(t,i)
        desired_link = xval
        break
print(xval.get_attribute('href'))
# Out:
# spider-man-(spiderman)-(2002) 4
# https://subscene.com/subtitles/spider-man-spiderman
