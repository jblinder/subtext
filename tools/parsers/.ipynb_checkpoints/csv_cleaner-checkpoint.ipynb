# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dateutil.parser
import seaborn as sns
from IPython.display import Image


# mother = Mother_Pandas()
# enables inline plots, without it plots don't show up in the notebook
''' Settings '''
sns.set_style("white")
pd.set_option('display.max_columns', 25)
pd.set_option('display.max_rows', 25)
pd.set_option('display.precision', 3)

''' Load and concatinate CSV files into single dataframe'''
csv_names = ['../../data/to_merge/imdb_decades.csv',
             '../../data/to_merge/imdb_extras.csv',
              '../../data/to_merge/imdb_HEAD.csv',
            '../../data/to_merge/imdb_oldies.csv']
files=[]
for path in csv_names:
    files.append(
        pd.read_csv(path)
    )
df = pd.concat(files)

# %%
df.count()
# Out:
# Unnamed: 0                    580
# budget                       1867
# cast                         2540
# color                        2555
# country                      2558
# description                  2551
# director                     2555
# genre                        2558
# gross_usa                    1751
# gross_usa_weekend            1341
# gross_worldwide              1284
# imdb_critic_reviews_total    2514
# imdb_popularity              1615
# imdb_rating                  2532
# imdb_ratings_total           2532
# imdb_user_reviews_total      2531
# language                     2470
# metacritic_rating             635
# mpaa_rating                  2467
# poster_image                 2554
# production_co                2552
# release_date                 2558
# runtime                      2451
# title                        2558
# year                         2556
# dtype: int64

# %%
df = df.drop_duplicates(subset='title')
df = df[df['mpaa_rating'].str.contains("TV") == False]
#df = df[df['year'] != None]
df.dropna(subset=['year'],inplace=True)
df['year'] =  df['year'].astype(int)
df
# Out:
#      Unnamed: 0           budget  \
# 0           NaN       $6,000,000
# 1           NaN              NaN
# 2           NaN              NaN
# 3           NaN              NaN
# 4           NaN    RUR 1,000,000
# 5           NaN         $300,000
# 6           NaN      $20,000,000
# 7           NaN       $1,000,000
# 8           NaN              NaN
# 9           NaN              NaN
# 10          NaN              NaN
# 11          NaN       $1,500,000
# ..          ...              ...
# 559       421.0       $3,300,000
# 566       429.0       €9,500,000
# 569       434.0       $7,500,000
# 571       436.0     $165,000,000
# 572       437.0  FRF 115,000,000
# 573       440.0       $6,000,000
# 17          NaN      $17,000,000
# 24          NaN         $422,000
# 26          NaN       $3,000,000
# 29          NaN       $6,000,000
# 32          NaN       $2,500,000
# 37          NaN              NaN
#
#                                                   cast             color  \
# 0    Marlon Brando,Al Pacino,James Caan,Richard S. ...             Color
# 1    Peter Falk,Gena Rowlands,Fred Draper,Lady Rowl...             Color
# 2    Eileen Brennan,Truman Capote,James Coco,Peter ...             Color
# 3    George Burns,Art Carney,Lee Strasberg,Charles ...             Color
# 4    Natalya Bondarchuk,Donatas Banionis,Jüri Järve...   Black and White
# 5    Marilyn Burns,Allen Danziger,Paul A. Partain,W...             Color
# 6    Richard Dreyfuss,François Truffaut,Teri Garr,M...             Color
# 7    Warren Oates,Ben Johnson,Michelle Phillips,Clo...   Black and White
# 8    Richard Attenborough,Judy Geeson,John Hurt,Pat...             Color
# 9    Paul Rogers,Ian Holm,Cyril Cusack,Terence Rigb...             Color
# 10   Robert Duvall,Karen Black,Joe Don Baker,Robert...             Color
# 11   Ron Leibman,David Selby,Sheila Frazier,Pat Hin...             Color
# ..                                                 ...               ...
# 559  Miles Teller,J.K. Simmons,Paul Reiser,Melissa ...             Color
# 566  François Cluzet,Omar Sy,Anne Le Ny,Audrey Fleu...             Color
# 569  Edward Norton,Edward Furlong,Beverly D'Angelo,...   Black and White
# 571  Ellen Burstyn,Matthew McConaughey,Mackenzie Fo...             Color
# 572  Jean Reno,Gary Oldman,Natalie Portman,Danny Ai...             Color
# 573  Stephen Baldwin,Gabriel Byrne,Benicio Del Toro...             Color
# 17   Audrey Hepburn,Rex Harrison,Stanley Holloway,W...             Color
# 24   Al Jolson,May McAvoy,Warner Oland,Eugenie Bess...   Black and White
# 26   Richard Burton,Ava Gardner,Deborah Kerr,Sue Ly...   Black and White
# 29   Natalie Wood,Richard Beymer,Russ Tamblyn,Rita ...             Color
# 32   Audrey Hepburn,George Peppard,Patricia Neal,Bu...             Color
# 37   Marcello Mastroianni,Anita Ekberg,Anouk Aimée,...   Black and White
#
#           country                                        description  \
# 0             USA  When the aging head of a famous crime family d...
# 1             USA  Peter Falk is a blue collar man trying to deal...
# 2             USA  Despite not knowing him, the world's most famo...
# 3             USA  Joe, Al, and Willie are three old men who have...
# 4    Soviet Union  The Solaris mission has established a base on ...
# 5             USA  En route to visit their grandfather's grave (w...
# 6             USA  Two parallel stories are told. In the first, a...
# 7             USA  After a shoot-out kills five FBI agents in Kan...
# 8              UK                                      London, 1949.
# 9              UK  Max is a surly pensioner who alternately vener...
# 10            USA  When the small criminal Macklin is released fr...
# 11            USA  Dave and Rob, fresh from the Police Academy, e...
# ..            ...                                                ...
# 559           USA  A young and talented drummer attending a prest...
# 566        France  In Paris, the aristocratic and intellectual Ph...
# 569           USA  Derek Vineyard is paroled after serving 3 year...
# 571           USA  Earth's future has been riddled by disasters, ...
# 572        France  After her father, mother, older sister and lit...
# 573           USA  Following a truck hijack in New York, five con...
# 17            USA  Pompous phonetics professor Henry Higgins is s...
# 24            USA  Cantor Rabinowitz is concerned and upset becau...
# 26            USA  The Rev. T. Lawrence Shannon has been living i...
# 29            USA  West Side Story is the award-winning adaptatio...
# 32            USA  Holly Golightly is a flighty Manhattan party g...
# 37          Italy  Journalist and man-about-town Marcello struggl...
#
#                  director                                   genre  \
# 0    Francis Ford Coppola                            Crime, Drama
# 1         John Cassavetes                          Drama, Romance
# 2            Robert Moore        Comedy, Mystery, Thriller, Crime
# 3            Martin Brest                    Comedy, Crime, Drama
# 4        Andrei Tarkovsky                  Drama, Mystery, Sci-Fi
# 5             Tobe Hooper                                  Horror
# 6        Steven Spielberg                           Drama, Sci-Fi
# 7             John Milius         Action, Biography, Crime, Drama
# 8       Richard Fleischer                 Biography, Crime, Drama
# 9              Peter Hall                                   Drama
# 10             John Flynn                  Crime, Thriller, Drama
# 11           Gordon Parks  Action, Comedy, Crime, Drama, Thriller
# ..                    ...                                     ...
# 559       Damien Chazelle                            Drama, Music
# 566       Olivier Nakache                Biography, Comedy, Drama
# 569             Tony Kaye                            Crime, Drama
# 571     Christopher Nolan                Adventure, Drama, Sci-Fi
# 572            Luc Besson                  Crime, Drama, Thriller
# 573          Bryan Singer                Crime, Mystery, Thriller
# 17           George Cukor         Drama, Family, Musical, Romance
# 24          Alan Crosland          Drama, Music, Musical, Romance
# 26            John Huston                                   Drama
# 29         Jerome Robbins          Crime, Drama, Musical, Romance
# 32          Blake Edwards                  Comedy, Drama, Romance
# 37       Federico Fellini                           Comedy, Drama
#
#          gross_usa gross_usa_weekend gross_worldwide  \
# 0    $134,966,411,          $302,393    $245,066,411
# 1              NaN               NaN             NaN
# 2     $32,511,047,               NaN             NaN
# 3      $26,869,286               NaN             NaN
# 4              NaN               NaN             NaN
# 5      $30,859,000               NaN             NaN
# 6     $132,088,635               NaN    $303,788,635
# 7              NaN               NaN             NaN
# 8              NaN               NaN             NaN
# 9              NaN               NaN             NaN
# 10             NaN               NaN             NaN
# 11             NaN               NaN             NaN
# ..             ...               ...             ...
# 559    $13,092,000          $135,388     $48,982,041
# 566    $13,182,281          $103,507    $426,480,871
# 569     $6,719,864          $156,076     $23,875,127
# 571   $188,020,017       $47,510,360    $675,020,017
# 572    $19,501,238        $5,306,558     $45,501,238
# 573    $23,341,568          $645,363     $34,449,356
# 17     $72,000,000               NaN             NaN
# 24      $7,630,000               NaN             NaN
# 26             NaN               NaN    $12,000,000,
# 29     $43,656,822               NaN             NaN
# 32     $8,000,000,               NaN    $14,000,000,
# 37     $19,516,000               NaN             NaN
#
#      imdb_critic_reviews_total imdb_popularity  imdb_rating  \
# 0                        223.0             111          9.2
# 1                         85.0             NaN          8.2
# 2                         61.0             NaN          7.4
# 3                         13.0             NaN          7.2
# 4                        173.0           2,543          8.1
# 5                        211.0           1,874          7.5
# 6                        209.0           1,752          7.7
# 7                         35.0             NaN          7.0
# 8                         55.0             NaN          7.6
# 9                         10.0             NaN          7.1
# 10                        33.0             NaN          7.1
# 11                        15.0             NaN          6.6
# ..                         ...             ...          ...
# 559                      557.0             335          8.5
# 566                      313.0             745          8.5
# 569                      157.0             582          8.5
# 571                      710.0             140          8.6
# 572                      170.0             252          8.6
# 573                      168.0             552          8.6
# 17                        83.0           2,594          7.9
# 24                        52.0             NaN          6.7
# 26                        44.0             NaN          7.8
# 29                       123.0           1,397          7.6
# 32                       163.0           1,125          7.7
# 37                       133.0           4,131          8.1
#
#     imdb_ratings_total imdb_user_reviews_total language  metacritic_rating  \
# 0            1,328,623                   2,707  English              100.0
# 1               16,465                      99  English                NaN
# 2               27,904                     172  English                NaN
# 3                2,426                      28  English                NaN
# 4               63,833                     253  Russian               90.0
# 5              111,810                     859  English               75.0
# 6              157,885                     373  English               90.0
# 7                3,916                      58  English                NaN
# 8                6,149                      81  English                NaN
# 9                  555                      13  English                NaN
# 10               2,544                      50  English                NaN
# 11                 629                      17  English                NaN
# ..                 ...                     ...      ...                ...
# 559            544,968                     897  English                NaN
# 566            613,924                     434   French                NaN
# 569            891,849                   1,461  English                NaN
# 571          1,165,890                   3,037  English                NaN
# 572            847,760                     915  English                NaN
# 573            846,843                   1,238  English                NaN
# 17              75,116                     276  English                NaN
# 24               7,728                      95  English                NaN
# 26               9,333                      91  English                NaN
# 29              81,726                     332  English               86.0
# 8                  29 January 1971 (UK)    111.0
# 9                16 April 1977 (France)    111.0
# 10              9 February 1974 (Japan)    103.0
# 11       11 October 1974 (West Germany)     90.0
# ..                                  ...      ...
# 559       15 October 2014 (Philippines)    107.0
# 566            2 November 2011 (France)    112.0
# 569              20 November 1998 (USA)    119.0
# 571               7 November 2014 (USA)    169.0
# 572              18 November 1994 (USA)    110.0
# 573             15 September 1995 (USA)    106.0
# 17               25 December 1964 (USA)    170.0
# 24                 6 October 1927 (USA)     88.0
# 26                  6 August 1964 (USA)    125.0
# 29             23 December 1961 (Japan)    153.0
# 32              4 November 1961 (Japan)    115.0
# 37                  19 April 1961 (USA)    174.0
#
#                                   title  year
# 0                         The Godfather  1972
# 1           A Woman Under the Influence  1974
# 2                       Murder by Death  1976
# 3                        Going in Style  1979
# 4                               Solaris  1972
# 5          The Texas Chain Saw Massacre  1974
# 6    Close Encounters of the Third Kind  1977
# 7                             Dillinger  1973
# 8                   10 Rillington Place  1971
# 9                        The Homecoming  1973
# 10                           The Outfit  1973
# 11                       The Super Cops  1974
# ..                                  ...   ...
# 559                            Whiplash  2014
# 566                    The Intouchables  2011
# 569                  American History X  1998
# 571                        Interstellar  2014
# 572               Lon: The Professional  1994
# 573                  The Usual Suspects  1995
# 17                         My Fair Lady  1964
# 24                      The Jazz Singer  1927
# 26              The Night of the Iguana  1964
# 29                      West Side Story  1961
# 32               Breakfast at Tiffany's  1961
# 37                        La Dolce Vita  1960
#
# [2053 rows x 25 columns]

# %%
df_clean = df[df['year'].isnull() == False]
df_clean.count()
# Out:
# Unnamed: 0                    340
# budget                       1514
# cast                         2045
# color                        2050
# country                      2053
# description                  2049
# director                     2050
# genre                        2053
# gross_usa                    1429
# gross_usa_weekend            1129
# gross_worldwide              1069
# imdb_critic_reviews_total    2021
# imdb_popularity              1303
# imdb_rating                  2027
# imdb_ratings_total           2027
# imdb_user_reviews_total      2028
# language                     2004
# metacritic_rating             556
# mpaa_rating                  2053
# poster_image                 2051
# production_co                2048
# release_date                 2053
# runtime                      1963
# title                        2053
# year                         2053
# dtype: int64

# %%
df_clean.groupby('year')['title'].count()
# Out:
# year
# 1900     4
# 1901     3
# 1902     4
# 1903     4
# 1904     2
# 1905     3
# 1906     3
# 1907     1
# 1908     3
# 1909     2
# 1910     1
# 1911     1
#         ..
# 2008    45
# 2009    43
# 2010    45
# 2011    44
# 2012    42
# 2013    48
# 2014    50
# 2015    43
# 2016    48
# 2017    80
# 2018    67
# 2019     5
# Name: title, Length: 120, dtype: int64

# %%
df_clean.to_csv(f"../../data/imdb_unique_prod-{datetime.datetime.now():%Y-%m-%d_%I%M}.csv")

# %%
import datetime
def timestamp_filename(fn,ext):
    print(f"{fn}-{datetime.datetime.now():%Y-%m-%d-%I%M}.{ext}")

timestamp_filename("yo","txt")
# Out:
# yo-2018-04-20-0923.txt

# %%
dr
# Out:
#   File "<ipython-input-35-b9b5477966b9>", line 1
#     df_clean['runtime'] df_clean['year'] df_clean['country']
#                                ^
# SyntaxError: invalid syntax

# %%
df_clean
