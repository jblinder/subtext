# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dateutil.parser
import seaborn as sns
from IPython.display import Image


# mother = Mother_Pandas()
# enables inline plots, without it plots don't show up in the notebook
''' Settings '''
sns.set_style("white")
pd.set_option('display.max_columns', 25)
pd.set_option('display.max_rows', 25)
pd.set_option('display.precision', 3)

''' Load and concatinate CSV files into single dataframe'''
csv_names = ['subtitles/vertigo.csv',
             'subtitles/12monkeys.csv',
             'subtitles/BlackPanther.csv',
             'subtitles/AlmostFamous.csv',
             'subtitles/Goodfellas.csv']
files=[]
for path in csv_names:
    files.append(
        pd.read_csv(path)
    )
df = pd.concat(files)


df['duration'] = df['startTime'] - df['endTime'].shift(1)
df['delta'] = df.groupby('movie')['endTime'].transform(pd.Series.diff)
#df = df.fillna(0)

df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-58-72b5d97f9a0b> in <module>()
#      24 for path in csv_names:
#      25     files.append(
# ---> 26         pd.read_csv(path)
#      27     )
#      28 df = pd.concat(files)
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dateutil.parser
import seaborn as sns
from IPython.display import Image
import os
fil_path = "../parsers/srt/subtitles/csv/"
dir_list = os.listdir(fil_path)

# mother = Mother_Pandas()
# enables inline plots, without it plots don't show up in the notebook
''' Settings '''
sns.set_style("white")
pd.set_option('display.max_columns', 25)
pd.set_option('display.max_rows', 25)
pd.set_option('display.precision', 3)

''' Load and concatinate CSV files into single dataframe'''

# want as many predictive features as possilbe
# how many movies? at least 10-20 * num_cols
files=[]
for path in dir_list:
    files.append(
        pd.read_csv(fil_path+path)
    )
df = pd.concat(files)

# some data frame with movie  + srt
# two seperat dataframes

df['duration'] = df['endTime'] - df['startTime']
df['delta'] = df.groupby('title')['endTime'].transform(pd.Series.diff)
df = df.fillna(0)
df_one = df[df['title'] == 'The Dark Knight']

# %%
df_one = df[df['title'] == 'The Dark Knight']
plt.hist(df_one['duration'],bins=100);

# %%
df_one = df[df['title'] == 'The Dark Knight']
#plt.hist(df_one['delta'],bins=100);

#plt.plot(df_one['startTime'],df_one['delta']);
plt.plot(df_one['startTime'],df_one['duration']);
plt.legend(['delta', 'line length'])
plt.show()

# %%
df_ro.sort_values(by='startTime')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-aa400488a2d8> in <module>()
# ----> 1 df_ro.sort_values(by='startTime')
#
# NameError: name 'df_ro' is not defined

# %%
df_one = df[df['title'] == 'American Sniper']
plt.hist(df_one['duration'],bins=100);

# %%
df_one = df[df['title'] == 'American Sniper']
plt.plot(df_one['startTime'],df_one['delta']);
plt.plot(df_one['startTime'],df_one['duration']);
plt.legend(['delta', 'line length'])
plt.show()

# %%
df_one = df[df['title'] == 'American Sniper']
plt.hist(df_one['delta'],bins=100);

# %%
df_one = df[df['title'] == 'Shrek 2']
plt.plot(df_one['startTime'],df_one['delta']);
plt.plot(df_one['startTime'],df_one['duration']);
plt.legend(['delta', 'line length'])
plt.show()

# %%
df_one = df[df['title'] == 'Shrek 2']
plt.hist(df_one['duration'],bins=100);

# %%
df_one = df[df['title'] == 'Shrek 2']
plt.hist(df_one['delta'],bins=100);

# %%
df_one = df[df['title'] == 'American Sniper']
plt.hist(df_one['duration'],bins=100);

# %%
df_one = df[df['title'] == 'American Sniper']
plt.hist(df_one['delta'],bins=100);

# %%
df_one = df[df['title'] == 'Spider-Man']
df['delta'] = df_one[df['delta'] < 10000]

plt.hist(df_one['delta'],bins=100);
# Out:
# /Users/justinblinder/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-53a8a5d9f408> in <module>()
#       1 df_one = df[df['title'] == 'Spider-Man']
# ----> 2 df['delta'] = df_one[df['delta'] < 10000]
#       3
#       4 plt.hist(df_one['delta'],bins=100);
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# ...

# %%
df_one = df[df['title'] == 'Forrest Gump']
#df_one
plt.hist(df_one['delta'],bins=100);
