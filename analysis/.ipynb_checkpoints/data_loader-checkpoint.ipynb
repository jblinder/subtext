# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dateutil.parser
import seaborn as sns
from IPython.display import Image
import os

fil_path = "../data/srt/srt_csv/"
dir_list = os.listdir(fil_path)

''' Settings '''
sns.set_style("white")
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 20)
pd.set_option('display.precision', 3)

''' Load and concatinate CSV files into single dataframe'''

files=[]
for path in dir_list:
    files.append(
        pd.read_csv(fil_path+path,index_col=0)
    )
df_sub = pd.concat(files)

csv_names = ['../data/imdb_unique_prod-2018-04-21_0924.csv']
files = []
for path in csv_names:
    files.append(
        pd.read_csv(path,index_col=0)
    )
df_movies = pd.concat(files)
df_movies = df_movies.loc[:, ~df_movies.columns.str.contains('^Unnamed')]

cols = df_movies.columns.tolist()
cols = cols[-2:] + cols[:-2]
df_movies = df_movies[cols]

# Drop null values
df_movies = df_movies[(df_movies['imdb_popularity'].notnull())]
df_movies['imdb_popularity'] = df_movies['imdb_popularity'].dropna()
len(df_movies)
df_movies.head(5)
# Out:
#                                  title  year         budget  \
# 0                        The Godfather  1972     $6,000,000
# 4                              Solaris  1972  RUR 1,000,000
# 5         The Texas Chain Saw Massacre  1974       $300,000
# 6   Close Encounters of the Third Kind  1977    $20,000,000
# 15                      Helter Skelter  1976            NaN
#
#                                                  cast             color  \
# 0   Marlon Brando,Al Pacino,James Caan,Richard S. ...             Color
# 4   Natalya Bondarchuk,Donatas Banionis,Jüri Järve...   Black and White
# 5   Marilyn Burns,Allen Danziger,Paul A. Partain,W...             Color
# 6   Richard Dreyfuss,François Truffaut,Teri Garr,M...             Color
# 15  George DiCenzo,Steve Railsback,Nancy Wolfe,Mar...             Color
#
#          country                                        description  \
# 0            USA  When the aging head of a famous crime family d...
# 4   Soviet Union  The Solaris mission has established a base on ...
# 5            USA  En route to visit their grandfather's grave (w...
# 6            USA  Two parallel stories are told. In the first, a...
# 15           USA  Chilling story of the investigation and trial ...
#
#                 director                   genre      gross_usa  \
# 0   Francis Ford Coppola            Crime, Drama  $134,966,411,
# 4       Andrei Tarkovsky  Drama, Mystery, Sci-Fi            NaN
# 5            Tobe Hooper                  Horror    $30,859,000
# 6       Steven Spielberg           Drama, Sci-Fi   $132,088,635
# 15             Tom Gries  Crime, Drama, Thriller            NaN
#
#    gross_usa_weekend gross_worldwide  imdb_critic_reviews_total  \
# 0           $302,393    $245,066,411                      223.0
# 4                NaN             NaN                      173.0
# 5                NaN             NaN                      211.0
# 6                NaN    $303,788,635                      209.0
# 15               NaN             NaN                       11.0
#
#    imdb_popularity  imdb_rating imdb_ratings_total imdb_user_reviews_total  \
# 0              111          9.2          1,328,623                   2,707
# 4            2,543          8.1             63,833                     253
# 5            1,874          7.5            111,810                     859
# 6            1,752          7.7            157,885                     373
# 15           4,757          7.4              2,862                      59
#
#    language  metacritic_rating mpaa_rating  \
# 0   English              100.0           R
# 4   Russian               90.0          PG
# 5   English               75.0           R
# 6   English               90.0          PG
# 15  English                NaN   Not Rated
#
#                                          poster_image  \
# 0   https://ia.media-imdb.com/images/M/MV5BM2MyNjY...
# 4   https://ia.media-imdb.com/images/M/MV5BZmY4Yjc...
# 5   https://ia.media-imdb.com/images/M/MV5BZDI3OWE...
# 6   https://ia.media-imdb.com/images/M/MV5BMjM1NjE...
# 15  https://ia.media-imdb.com/images/M/MV5BMTc0OTQ...
#
#                                       production_co  \
# 0                                Paramount Pictures
# 4                                           Mosfilm
# 5                                            Vortex
# 6   Julia Phillips and Michael Phillips Productions
# 15                              Lorimar Productions
#
#                           release_date  runtime
# 0                  24 March 1972 (USA)    175.0
# 4   26 September 1972 (Czechoslovakia)    167.0
# 5                 4 October 1974 (USA)     83.0
# 6               14 December 1977 (USA)    133.0
# 15                  1 April 1976 (USA)    194.0

# %%
df_movies_missing = df_movies[df_movies['gross_usa'].isnull()]
df_movies_missing.head(5)
# Out:
#                 title  year         budget  \
# 4             Solaris  1972  RUR 1,000,000
# 15     Helter Skelter  1976            NaN
# 123           Network  1976            NaN
# 136  The Seventh Seal  1957       $150,000
# 139    Fahrenheit 451  1966     $1,500,000
#
#                                                   cast             color  \
# 4    Natalya Bondarchuk,Donatas Banionis,Jüri Järve...   Black and White
# 15   George DiCenzo,Steve Railsback,Nancy Wolfe,Mar...             Color
# 123  Faye Dunaway,William Holden,Peter Finch,Robert...             Color
# 136  Gunnar Björnstrand,Bengt Ekerot,Nils Poppe,Max...   Black and White
# 139  Julie Christie,Oskar Werner,Cyril Cusack,Anton...             Color
#
#           country                                        description  \
# 4    Soviet Union  The Solaris mission has established a base on ...
# 15            USA  Chilling story of the investigation and trial ...
# 123           USA  In the 1970s, terrorist violence is the stuff ...
# 136        Sweden  A Knight and his squire are home from the crus...
# 139            UK  Based on the 1951 Ray Bradbury novel of the sa...
#
#               director                   genre gross_usa gross_usa_weekend  \
# 4     Andrei Tarkovsky  Drama, Mystery, Sci-Fi       NaN               NaN
# 15           Tom Gries  Crime, Drama, Thriller       NaN               NaN
# 123       Sidney Lumet                   Drama       NaN               NaN
# 136     Ingmar Bergman          Drama, Fantasy       NaN               NaN
# 139  François Truffaut           Drama, Sci-Fi       NaN               NaN
#
#     gross_worldwide  imdb_critic_reviews_total imdb_popularity  imdb_rating  \
# 4               NaN                      173.0           2,543          8.1
# 15              NaN                       11.0           4,757          7.4
# 123             NaN                      149.0           2,113          8.1
# 136             NaN                      143.0           2,428          8.2
# 139             NaN                       75.0           1,442          7.3
#
#     imdb_ratings_total imdb_user_reviews_total language  metacritic_rating  \
# 4               63,833                     253  Russian               90.0
# 15               2,862                      59  English                NaN
# 123            122,319                     337  English               88.0
# 136            132,185                     290  Swedish                NaN
# 139             36,295                     181  English                NaN
#
#     mpaa_rating                                       poster_image  \
# 4            PG  https://ia.media-imdb.com/images/M/MV5BZmY4Yjc...
# 15    Not Rated  https://ia.media-imdb.com/images/M/MV5BMTc0OTQ...
# 123           R  https://ia.media-imdb.com/images/M/MV5BNmFiOWY...
# 136   Not Rated  https://ia.media-imdb.com/images/M/MV5BYWRiNDU...
# 139   Not Rated  https://ia.media-imdb.com/images/M/MV5BMjI3MzI...
#
#                  production_co                        release_date  runtime
# 4                      Mosfilm  26 September 1972 (Czechoslovakia)    167.0
# 15         Lorimar Productions                  1 April 1976 (USA)    194.0
# 123  Metro-Goldwyn-Mayer (MGM)              27 November 1976 (USA)    121.0
# 136   Svensk Filmindustri (SF)               13 October 1958 (USA)     96.0
# 139          Anglo Enterprises              14 November 1966 (USA)    112.0

# %%
# Import numbers

csv_names = ['../data/numbers_worldwide-1-5.csv','../data/numbers_worldwide-6-50.csv']
files = []
for path in csv_names:
    files.append(
        pd.read_csv(path,index_col=0)
    )
df_numbers = pd.concat(files)
df_numbers = df_numbers.reset_index()
df_numbers['title'] = df_numbers['title'].str.replace(r"\(.*\)","")
#df_numbers[df_numbers['title'].str.contains('Casino')]
df_all = pd.merge(df_movies_missing,df_numbers[['numbers_gross_domestic']], on='title')
df_all
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'title'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-d50024c77984> in <module>()
#      11 df_numbers['title'] = df_numbers['title'].str.replace(r"\(.*\)","")
#      12 #df_numbers[df_numbers['title'].str.contains('Casino')]
# ---> 13 df_all = pd.merge(df_movies_missing,df_numbers[['numbers_gross_domestic']], on='title')
#      14 df_all
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      55                          right_index=right_index, sort=sort, suffixes=suffixes,
#      56                          copy=copy, indicator=indicator,
# ---> 57                          validate=validate)
#      58     return op.get_result()
#      59
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     563         (self.left_join_keys,
#     564          self.right_join_keys,
# --> 565          self.join_names) = self._get_merge_keys()
#     566
#     567         # validate the merge keys dtypes. We may need to coerce
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     822                     if not is_rkey(rk):
#     823                         if rk is not None:
# --> 824                             right_keys.append(right[rk]._values)
#     825                         else:
#     826                             # work-around for merge_asof(right_index=True)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'title'

# %%
''' Parse numerics'''
# Drop rows with null values
df_movies = df_movies[(df_movies['budget'].notnull())]
df_movies = df_movies[(df_movies['gross_usa'].notnull())]
df_movies = df_movies[(df_movies['gross_usa_weekend'].notnull())]
df_movies = df_movies[(df_movies['gross_worldwide'].notnull())]
df_movies = df_movies[(df_movies['imdb_rating'].notnull())]
#df_movies = df_movies[(df_movies['metacritic_rating'].notnull())]
#df_movies = df_movies[(df_movies['imdb_popularity'].notnull())]

# Convert data types
df_movies['imdb_popularity'] = pd.to_numeric(df_movies['imdb_popularity'], errors='coerce').astype(float)
df_movies['year'] =  df_movies['year'].astype(int)
#df_movies['imdb_popularity'] = df_movies['imdb_popularity'].dropna()
#df_movies['imdb_critic_reviews_total'] = pd.to_numeric(df_movies['imdb_critic_reviews_total'], errors='coerce').astype(int)
#df_movies['imdb_user_reviews_total'] = pd.to_numeric(df_movies['imdb_user_reviews_total'], errors='coerce').astype(int)
df_movies.head(5)
# Out:
#                    title  year       budget  \
# 0          The Godfather  1972   $6,000,000
# 20              Superman  1978  $55,000,000
# 43                 Alien  1979  $11,000,000
# 48  The Spy Who Loved Me  1977  $14,000,000
# 57    Gone with the Wind  1939   $3,977,000
#
#                                                  cast  color country  \
# 0   Marlon Brando,Al Pacino,James Caan,Richard S. ...  Color     USA
# 20  Marlon Brando,Gene Hackman,Christopher Reeve,N...  Color     USA
# 43  Tom Skerritt,Sigourney Weaver,Veronica Cartwri...  Color      UK
# 48  Roger Moore,Barbara Bach,Curd Jürgens,Richard ...  Color      UK
# 57  Thomas Mitchell,Barbara O'Neil,Vivien Leigh,Ev...  Color     USA
#
#                                           description              director  \
# 0   When the aging head of a famous crime family d...  Francis Ford Coppola
# 20  Just before the destruction of the planet Kryp...        Richard Donner
# 43  In the distant future, the crew of the commerc...          Ridley Scott
# 48  James Bond is back again and his new mission i...         Lewis Gilbert
# 57  Scarlett is a woman who can deal with a nation...        Victor Fleming
#
#                                genre      gross_usa gross_usa_weekend  \
# 0                       Crime, Drama  $134,966,411,          $302,393
# 20  Action, Adventure, Drama, Sci-Fi   $134,218,018        $7,465,343
# 43                    Horror, Sci-Fi    $78,900,000        $3,527,881
# 48       Action, Adventure, Thriller    $46,800,000        $1,347,927
# 57      Drama, History, Romance, War   $198,676,459        $1,192,593
#
#    gross_worldwide  imdb_critic_reviews_total  imdb_popularity  imdb_rating  \
# 0     $245,066,411                      223.0            111.0          9.2
# 20    $166,200,000                      176.0              NaN          7.3
# 43    $203,630,630                      424.0            340.0          8.5
# 48    $185,400,000                      111.0              NaN          7.1
# 57    $400,176,459                      168.0            600.0          8.2
#
#    imdb_ratings_total imdb_user_reviews_total language  metacritic_rating  \
# 0           1,328,623                   2,707  English              100.0
# 20            140,063                     517  English               86.0
# 43            663,691                   1,233  English               83.0
# 48             84,603                     289  English                NaN
# 57            247,789                     749  English               97.0
#
#    mpaa_rating                                       poster_image  \
# 0            R  https://ia.media-imdb.com/images/M/MV5BM2MyNjY...
# 20          PG  https://ia.media-imdb.com/images/M/MV5BOWU0ZGE...
# 43           R  https://ia.media-imdb.com/images/M/MV5BNDNhN2I...
# 48          PG  https://ia.media-imdb.com/images/M/MV5BNDk3ODM...
# 57           G  https://ia.media-imdb.com/images/M/MV5BYWQwOWV...
#
#                       production_co            release_date  runtime
# 0                Paramount Pictures     24 March 1972 (USA)    175.0
# 20                   Dovemead Films  15 December 1978 (USA)    143.0
# 43           Brandywine Productions      22 June 1979 (USA)    116.0
# 48                  Eon Productions     3 August 1977 (USA)    125.0
# 57  Selznick International Pictures   17 January 1940 (USA)    238.0

# %%
from currency_converter import CurrencyConverter
from re import sub
import math

c = CurrencyConverter()

def parse_currency(value):
    value = str(value)
    currency_type = sub(r'[?!^\d.]', '', value ).replace(',','').rstrip()
    currency_amount = sub(r'[^\d.]', '', value)
    if currency_type == "$":
        currency_type = 'USD'
    if currency_type == "€":
        currency_type = 'EUR'
    if currency_type == "£":
        currency_type = 'GBP'
    if currency_type == "RUR":
        currency_type = 'USD'
    if currency_type == "FRF":
        currency_type = 'EUR'
    if currency_type == "DEM":
        currency_type = 'EUR'
    if currency_type == "":
        currency_type = 'USD'        
    return int(math.ceil(c.convert(currency_amount, currency_type, 'USD')))
    
        


#df_movies = df_movies[df_movies['gross_usa'].notnull()]
#df_movies['gross_usa'] = df_movies['gross_usa'].apply(clean_imdb_box_office)
df_movies['budget'] = df_movies['budget'].apply(parse_currency)
df_movies['gross_usa'] = df_movies['gross_usa'].apply(parse_currency)
df_movies['gross_usa_weekend'] = df_movies['gross_usa_weekend'].apply(parse_currency)
df_movies['gross_worldwide'] = df_movies['gross_worldwide'].apply(parse_currency)

df_movies.head(5)
#df_movies
# Out:
#                    title  year    budget  \
# 0          The Godfather  1972   6000000
# 20              Superman  1978  55000000
# 43                 Alien  1979  11000000
# 48  The Spy Who Loved Me  1977  14000000
# 57    Gone with the Wind  1939   3977000
#
#                                                  cast  color country  \
# 0   Marlon Brando,Al Pacino,James Caan,Richard S. ...  Color     USA
# 20  Marlon Brando,Gene Hackman,Christopher Reeve,N...  Color     USA
# 43  Tom Skerritt,Sigourney Weaver,Veronica Cartwri...  Color      UK
# 48  Roger Moore,Barbara Bach,Curd Jürgens,Richard ...  Color      UK
# 57  Thomas Mitchell,Barbara O'Neil,Vivien Leigh,Ev...  Color     USA
#
#                                           description              director  \
# 0   When the aging head of a famous crime family d...  Francis Ford Coppola
# 20  Just before the destruction of the planet Kryp...        Richard Donner
# 43  In the distant future, the crew of the commerc...          Ridley Scott
# 48  James Bond is back again and his new mission i...         Lewis Gilbert
# 57  Scarlett is a woman who can deal with a nation...        Victor Fleming
#
#                                genre  gross_usa  gross_usa_weekend  \
# 0                       Crime, Drama  134966411             302393
# 20  Action, Adventure, Drama, Sci-Fi  134218018            7465343
# 43                    Horror, Sci-Fi   78900000            3527881
# 48       Action, Adventure, Thriller   46800000            1347928
# 57      Drama, History, Romance, War  198676460            1192593
#
#     gross_worldwide  imdb_critic_reviews_total  imdb_popularity  imdb_rating  \
# 0         245066411                      223.0            111.0          9.2
# 20        166200000                      176.0              NaN          7.3
# 43        203630630                      424.0            340.0          8.5
# 48        185400000                      111.0              NaN          7.1
# 57        400176460                      168.0            600.0          8.2
#
#    imdb_ratings_total imdb_user_reviews_total language  metacritic_rating  \
# 0           1,328,623                   2,707  English              100.0
# 20            140,063                     517  English               86.0
# 43            663,691                   1,233  English               83.0
# 48             84,603                     289  English                NaN
# 57            247,789                     749  English               97.0
#
#    mpaa_rating                                       poster_image  \
# 0            R  https://ia.media-imdb.com/images/M/MV5BM2MyNjY...
# 20          PG  https://ia.media-imdb.com/images/M/MV5BOWU0ZGE...
# 43           R  https://ia.media-imdb.com/images/M/MV5BNDNhN2I...
# 48          PG  https://ia.media-imdb.com/images/M/MV5BNDk3ODM...
# 57           G  https://ia.media-imdb.com/images/M/MV5BYWQwOWV...
#
#                       production_co            release_date  runtime
# 0                Paramount Pictures     24 March 1972 (USA)    175.0
# 20                   Dovemead Films  15 December 1978 (USA)    143.0
# 43           Brandywine Productions      22 June 1979 (USA)    116.0
# 48                  Eon Productions     3 August 1977 (USA)    125.0
# 57  Selznick International Pictures   17 January 1940 (USA)    238.0

# %%
# Calculate length of line dialogue 
df_sub['line_duration'] = df_sub['endTime'] - df_sub['startTime']

# Calculate length of line dialogue
# THIS LINE TOTALLY CHNAGES GRAPHS, IF SHIFT IS 1 vs -1
df_sub['line_delta'] = df_sub['startTime'] - df_sub['endTime'].shift(1)
df_sub['line_delta'] = df_sub['line_delta'].fillna(0).astype(int)
df_movies['genre'] = df_movies['genre'].dropna()

# Fix dupliacte index TODO: WHY IS THIS HAPPENING?
#df_movies = df_movies.reset_index()

# Create dummy variables
#df_movies['genre'] = df_movies['genre'].str.get_dummies(sep=',').add_prefix('genre_')
#df_movies[] = pd.get_dummies(df_movies['genre'])

# Merge subtitle and movie dataframe
#df_test = pd.merge(df_sub, df_movies[['title','year','genre','budget','imdb_rating','imdb_popularity','color','director','country','metacritic_rating','mpaa_rating','gross_usa','gross_usa_weekend','gross_worldwide']], on='title')
#df_test = df_test.groupby('title').agg(lambda x: x[x>0].mean()).reset_index()
#df_movies.index.get_duplicates()

df_movies
# Out:
#                       title  year     budget  \
# 0             The Godfather  1972    6000000
# 20                 Superman  1978   55000000
# 43                    Alien  1979   11000000
# 48     The Spy Who Loved Me  1977   14000000
# 57       Gone with the Wind  1939    3977000
# 65   Picnic at Hanging Rock  1975     349421
# 117                 Vertigo  1958    2479000
# 133             Rear Window  1954    1000000
# 199                    Jaws  1975    8000000
# 200                   Rocky  1976     960000
# ..                      ...   ...        ...
# 544          Disaster Movie  2008   20000000
# 556                 Memento  2000    9000000
# 557            The Prestige  2006   40000000
# 558               Gladiator  2000  103000000
# 559                Whiplash  2014    3300001
# 566        The Intouchables  2011   11840800
# 569      American History X  1998    7500000
# 571            Interstellar  2014  165000000
# 572   Lon: The Professional  1994  143336000
# 573      The Usual Suspects  1995    6000000
#
#                                                   cast             color  \
# 0    Marlon Brando,Al Pacino,James Caan,Richard S. ...             Color
# 20   Marlon Brando,Gene Hackman,Christopher Reeve,N...             Color
# 43   Tom Skerritt,Sigourney Weaver,Veronica Cartwri...             Color
# 48   Roger Moore,Barbara Bach,Curd Jürgens,Richard ...             Color
# 57   Thomas Mitchell,Barbara O'Neil,Vivien Leigh,Ev...             Color
# 65   Rachel Roberts,Vivean Gray,Helen Morse,Kirsty ...             Color
# 117  James Stewart,Kim Novak,Barbara Bel Geddes,Tom...             Color
# 133  James Stewart,Grace Kelly,Wendell Corey,Thelma...             Color
# 199  Roy Scheider,Robert Shaw,Richard Dreyfuss,Lorr...             Color
# 200  Sylvester Stallone,Talia Shire,Burt Young,Carl...             Color
# ..                                                 ...               ...
# 544  Matt Lanter,Vanessa Lachey,Gary 'G. Thang' Joh...             Color
# 556  Guy Pearce,Carrie-Anne Moss,Joe Pantoliano,Mar...   Black and White
# 557  Hugh Jackman,Christian Bale,Michael Caine,Pipe...             Color
# 558  Russell Crowe,Joaquin Phoenix,Connie Nielsen,O...             Color
# 559  Miles Teller,J.K. Simmons,Paul Reiser,Melissa ...             Color
# 566  François Cluzet,Omar Sy,Anne Le Ny,Audrey Fleu...             Color
# 569  Edward Norton,Edward Furlong,Beverly D'Angelo,...   Black and White
# 571  Ellen Burstyn,Matthew McConaughey,Mackenzie Fo...             Color
# 572  Jean Reno,Gary Oldman,Natalie Portman,Danny Ai...             Color
# 573  Stephen Baldwin,Gabriel Byrne,Benicio Del Toro...             Color
#
#        country                                        description  \
# 0          USA  When the aging head of a famous crime family d...
# 20         USA  Just before the destruction of the planet Kryp...
# 43          UK  In the distant future, the crew of the commerc...
# 48          UK  James Bond is back again and his new mission i...
# 57         USA  Scarlett is a woman who can deal with a nation...
# 65   Australia  Three students and a school teacher disappear ...
# 117        USA  John "Scottie" Ferguson is a retired San Franc...
# 133        USA  Professional photographer L.B. "Jeff" Jefferie...
# 199        USA  It's a hot summer on Amity Island, a small com...
# 200        USA  Rocky Balboa is a struggling boxer trying to m...
# ..         ...                                                ...
# 544        USA  Will, Lisa, and two of their friends attempt t...
# 556        USA  Memento chronicles two separate stories of Leo...
# 557        USA  In the end of the Nineteenth Century, in Londo...
# 558        USA  Maximus is a powerful Roman general, loved by ...
# 559        USA  A young and talented drummer attending a prest...
# 566     France  In Paris, the aristocratic and intellectual Ph...
# 569        USA  Derek Vineyard is paroled after serving 3 year...
# 571        USA  Earth's future has been riddled by disasters, ...
# 572     France  After her father, mother, older sister and lit...
# 573        USA  Following a truck hijack in New York, five con...
#
#                  director                             genre  gross_usa  \
# 0    Francis Ford Coppola                      Crime, Drama  134966411
# 20         Richard Donner  Action, Adventure, Drama, Sci-Fi  134218018
# 43           Ridley Scott                    Horror, Sci-Fi   78900000
# 48          Lewis Gilbert       Action, Adventure, Thriller   46800000
# 57         Victor Fleming      Drama, History, Romance, War  198676460
# 65             Peter Weir                    Drama, Mystery     232202
# 117      Alfred Hitchcock        Mystery, Romance, Thriller    3200000
# 133      Alfred Hitchcock                 Mystery, Thriller   36764313
# 199      Steven Spielberg        Adventure, Drama, Thriller  260000001
# 200      John G. Avildsen                      Drama, Sport  117235247
# ..                    ...                               ...        ...
# 544       Jason Friedberg                            Comedy   14190901
# 556     Christopher Nolan                 Mystery, Thriller   25544867
# 557     Christopher Nolan  Drama, Mystery, Sci-Fi, Thriller   53089891
# 558          Ridley Scott          Action, Adventure, Drama  187705427
# 559       Damien Chazelle                      Drama, Music   13092000
# 566       Olivier Nakache          Biography, Comedy, Drama   13182281
# 569             Tony Kaye                      Crime, Drama    6719864
# 571     Christopher Nolan          Adventure, Drama, Sci-Fi  188020017
# 572            Luc Besson            Crime, Drama, Thriller   19501238
# 573          Bryan Singer          Crime, Mystery, Thriller   23341568
#
#      gross_usa_weekend  gross_worldwide  imdb_critic_reviews_total  \
# 0               302393        245066411                      223.0
# 20             7465343        166200000                      176.0
# 43             3527881        203630630                      424.0
# 48             1347928        185400000                      111.0
# 57             1192593        400176460                      168.0
# 65               27492          6953633                      144.0
# 117              10783         25000000                      213.0
# 133             234258         36888916                      143.0
# 199            7061513        470653000                      386.0
# 200            5000000        225000000                      157.0
# ..                 ...              ...                        ...
# 544            6945535         34816824                      108.0
# 556             235488         39723096                      273.0
# 557           14801808        109676311                      357.0
# 558           34819017        457640427                      235.0
# 559             135388         48982041                      557.0
# 566             103507        426480871                      313.0
# 569             156076         23875127                      157.0
# 571           47510360        675020017                      710.0
# 572            5306558         45501238                      170.0
# 573             645363         34449356                      168.0
#
#      imdb_popularity  imdb_rating imdb_ratings_total imdb_user_reviews_total  \
# 0              111.0          9.2          1,328,623                   2,707
# 20               NaN          7.3            140,063                     517
# 43             340.0          8.5            663,691                   1,233
# 48               NaN          7.1             84,603                     289
# 57             600.0          8.2            247,789                     749
# 65               NaN          7.6             28,107                     208
# 117              NaN          8.3            294,947                     740
# 133              NaN          8.5            368,274                     704
# 199            305.0          8.0            476,643                   1,044
# 200            961.0          8.1            439,258                     590
# ..               ...          ...                ...                     ...
# 544              NaN          1.9             79,530                     364
# 556            618.0          8.5            967,238                   2,133
# 557            344.0          8.5            987,704                   1,163
# 558            274.0          8.5          1,125,411                   2,417
# 559            335.0          8.5            544,968                     897
# 566            745.0          8.5            613,924                     434
# 569            582.0          8.5            891,849                   1,461
# 571            140.0          8.6          1,165,890                   3,037
# 572            252.0          8.6            847,760                     915
# 573            552.0          8.6            846,843                   1,238
#
#     language  metacritic_rating mpaa_rating  \
# 0    English              100.0           R
# 20   English               86.0          PG
# 43   English               83.0           R
# 48   English                NaN          PG
# 57   English               97.0           G
# 65   English               81.0          PG
# 117  English                NaN          PG
# 133  English              100.0          PG
# 199  English               87.0          PG
# 200  English               69.0          PG
# ..       ...                ...         ...
# 544  English                NaN       PG-13
# 556  English                NaN           R
# 557  English                NaN       PG-13
# 558  English                NaN           R
# 559  English                NaN           R
# 566   French                NaN           R
# 569  English                NaN           R
# 571  English                NaN       PG-13
# 572  English                NaN           R
# 573  English                NaN           R
#
#                                           poster_image  \
# 0    https://ia.media-imdb.com/images/M/MV5BM2MyNjY...
# 20   https://ia.media-imdb.com/images/M/MV5BOWU0ZGE...
# 43   https://ia.media-imdb.com/images/M/MV5BNDNhN2I...
# 48   https://ia.media-imdb.com/images/M/MV5BNDk3ODM...
# 57   https://ia.media-imdb.com/images/M/MV5BYWQwOWV...
# 65   https://ia.media-imdb.com/images/M/MV5BYmI4N2E...
# 117  https://ia.media-imdb.com/images/M/MV5BYTE4ODE...
# 133  https://ia.media-imdb.com/images/M/MV5BNGUxYWM...
# 199  https://ia.media-imdb.com/images/M/MV5BMmVmODY...
# 200  https://ia.media-imdb.com/images/M/MV5BMTY5MDM...
# ..                                                 ...
# 544  https://ia.media-imdb.com/images/M/MV5BMTIzMDQ...
# 556  https://ia.media-imdb.com/images/M/MV5BZTcyNjk...
# 557  https://ia.media-imdb.com/images/M/MV5BMjA4NDI...
# 558  https://ia.media-imdb.com/images/M/MV5BMDliMmN...
# 559  https://ia.media-imdb.com/images/M/MV5BOTA5NDZ...
# 566  https://ia.media-imdb.com/images/M/MV5BMTYxNDA...
# 569  https://ia.media-imdb.com/images/M/MV5BZjA0MTM...
# 571  https://ia.media-imdb.com/images/M/MV5BZjdkOTU...
# 572  https://ia.media-imdb.com/images/M/MV5BZDAwYTl...
# 573  https://ia.media-imdb.com/images/M/MV5BYTViNjM...
#
#                        production_co                   release_date  runtime
# 0                 Paramount Pictures            24 March 1972 (USA)    175.0
# 20                    Dovemead Films         15 December 1978 (USA)    143.0
# 43            Brandywine Productions             22 June 1979 (USA)    116.0
# 48                   Eon Productions            3 August 1977 (USA)    125.0
# 57   Selznick International Pictures          17 January 1940 (USA)    238.0
# 65   Australian Film Commission, The          2 February 1979 (USA)    115.0
# 117  Alfred J. Hitchcock Productions          21 July 1958 (Brazil)    128.0
# 133  Alfred J. Hitchcock Productions           September 1954 (USA)    112.0
# 199         Zanuck/Brown Productions             20 June 1975 (USA)    124.0
# 200     Chartoff-Winkler Productions          3 December 1976 (USA)    120.0
# ..                               ...                            ...      ...
# 544                        Lionsgate           29 August 2008 (USA)     87.0
# 556          Newmarket Capital Group              25 May 2001 (USA)    113.0
# 557              Touchstone Pictures          20 October 2006 (USA)    130.0
# 558                       DreamWorks               5 May 2000 (USA)    155.0
# 559                       Bold Films  15 October 2014 (Philippines)    107.0
# 566                 Quad Productions       2 November 2011 (France)    112.0
# 569                  New Line Cinema         20 November 1998 (USA)    119.0
# 571               Paramount Pictures          7 November 2014 (USA)    169.0
# 572                          Gaumont         18 November 1994 (USA)    110.0
# 573    PolyGram Filmed Entertainment        15 September 1995 (USA)    106.0
#
# [895 rows x 24 columns]

# %%
from matplotlib import rcParams

plt.style.use('fivethirtyeight')
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
rcParams['figure.figsize'] = 11.7,8.27
df_test = df_test[(df_test['budget'] < 500000000) & (df_test['gross_usa'] < 4000000000) & (df_test['gross_usa_weekend'] < 500000000) & (df_test['gross_worldwide'] < 100000000) & (df_test['imdb_rating'] < 8)]

sns.lmplot(x='budget',y='line_duration',data=df_test,fit_reg=True) 
sns.lmplot(x='budget',y='line_delta',data=df_test,fit_reg=True) 


sns.lmplot(x='gross_usa',y='line_duration',data=df_test,fit_reg=True) 
sns.lmplot(x='gross_usa',y='line_delta',data=df_test,fit_reg=True) 


sns.lmplot(x='gross_usa_weekend',y='line_duration',data=df_test,fit_reg=True) 
sns.lmplot(x='gross_usa_weekend',y='line_delta',data=df_test,fit_reg=True) 

sns.lmplot(x='gross_worldwide',y='line_duration',data=df_test,fit_reg=True) 
sns.lmplot(x='gross_worldwide',y='line_delta',data=df_test,fit_reg=True) 

sns.lmplot(x='imdb_rating',y='line_duration',data=df_test,fit_reg=True) 
sns.lmplot(x='imdb_rating',y='line_delta',data=df_test,fit_reg=True) 

sns.lmplot(x='imdb_popularity',y='line_duration',data=df_test,fit_reg=True) 
sns.lmplot(x='imdb_popularity',y='line_delta',data=df_test,fit_reg=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-ba461a086954> in <module>()
#       5 sns.set(rc={'figure.figsize':(11.7,8.27)})
#       6 rcParams['figure.figsize'] = 11.7,8.27
# ----> 7 df_test = df_test[(df_test['budget'] < 500000000) & (df_test['gross_usa'] < 4000000000) & (df_test['gross_usa_weekend'] < 500000000) & (df_test['gross_worldwide'] < 100000000) & (df_test['imdb_rating'] < 8)]
#       8
#       9 sns.lmplot(x='budget',y='line_duration',data=df_test,fit_reg=True)
#
# NameError: name 'df_test' is not defined

# %%
df_r = df_test[['year','startTime','endTime','line_duration','line_delta','imdb_rating']]
df_r

# %%
''' Merge tables for regression'''
df_reg = pd.merge(df_sub, df_mov[['title','year','genre','budget','imdb_rating','imdb_popularity','color','director','country','metacritic_rating','mpaa_rating']], on='title')
df_reg.head(5)

# %%
df_test.corr()

# %%
import seaborn as sns
sns.set(font_scale=2)
sns.pairplot(df_test[df_test['year'] > 1950],size = 4)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV

import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.sandbox.regression.predstd import wls_prediction_std
df_r = df_r[['year','line_duration','line_delta']]
# Create an empty model
lr = LinearRegression()
df_r = df_r[df_r['year'] > 1940]
# Choose the predictor variables, here all but the first which is the response variable
# This model is analogous to the Y ~ X1 + X2 + X3 + X4 + X5 + X6 model
X = df_r.iloc[:,1:]
# Choose the response variable(s)
y = df_r.iloc[:,0]
# Fit the model to the full dataset
lr.fit(X,y)
# Print out the R^2 for the model against the full dataset


model = ols("line_duration ~ year", data=df_r).fit()
fig = plt.figure(figsize=(15,8))

# pass in the model as the first parameter, then specify the 
# predictor variable we want to analyze
fig = sm.graphics.plot_regress_exog(model, "year", fig=fig)
lr.score(X,y)

# %%
lsm = smf.ols('year~ line_delta + line_duration + imdb_rating', data = df_r)
fit1 = lsm.fit()
fit1.summary()

# %%
fit1.resid.plot(style='o', figsize=(12,8))
